# %% [markdown]
# # Project 2a: Lexical Semantics and Word Vectors (40 pts)

# %%
# %%bash
#
#   echo "Downloading files if missing"
#   git clone https://github.com/kabirahuja2431/CSE447-547MAutumn2024.git
#   cp -r ./CSE447-547MAutumn2024/"Project 2"/data .
#   cp ./CSE447-547MAutumn2024/"Project 2"/wordvec_tests.py .
#   cp ./CSE447-547MAutumn2024/"Project 2"/nn_tests.py .
#   cp ./CSE447-547MAutumn2024/"Project 2"/glove.py .
#   cp ./CSE447-547MAutumn2024/"Project 2"/siqa.py .
#   wget https://homes.cs.washington.edu/~kahuja/cse447/project2/glove.6B.50d.txt -O data/embeddings/glove.6B/glove.6B.50d.txt
# Out:
# Couldn't find program: 'bash'

# %% [markdown]
# Windows Alternative:

# %%
# import os
# import subprocess
# import shutil
# 
# # Clone the repository if it doesn't exist
# if not os.path.exists("CSE447-547MAutumn2024"):
#     print("Downloading files if missing")
#     subprocess.run(["git", "clone", "https://github.com/kabirahuja2431/CSE447-547MAutumn2024.git"])
# 
# # Define paths
# source_dir = os.path.join("CSE447-547MAutumn2024", "Project 2")
# dest_dir = "data"
# os.makedirs(dest_dir, exist_ok=True)
# os.makedirs(os.path.join(dest_dir, "embeddings", "glove.6B"), exist_ok=True)
# 
# # Copy necessary files
# shutil.copytree(os.path.join(source_dir, "data"), dest_dir, dirs_exist_ok=True)
# shutil.copy(os.path.join(source_dir, "wordvec_tests.py"), ".")
# shutil.copy(os.path.join(source_dir, "nn_tests.py"), ".")
# shutil.copy(os.path.join(source_dir, "glove.py"), ".")
# shutil.copy(os.path.join(source_dir, "siqa.py"), ".")
# 
# # Download file
# url = "https://homes.cs.washington.edu/~kahuja/cse447/project2/glove.6B.50d.txt"
# output_path = os.path.join(dest_dir, "embeddings", "glove.6B", "glove.6B.50d.txt")
# subprocess.run(["curl", "-o", output_path, url])

# %%
# Install required packages
import sys
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install sentence-transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\programdata\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sentence-transformers in c:\users\rohan mukherjee\appdata\roaming\python\python312\site-packages (3.2.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in c:\users\rohan mukherjee\appdata\roaming\python\python312\site-packages (from sentence-transformers) (4.46.1)
# Requirement already satisfied: tqdm in c:\programdata\anaconda3\lib\site-packages (from sentence-transformers) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in c:\users\rohan mukherjee\appdata\roaming\python\python312\site-packages (from sentence-transformers) (2.5.1+cu118)
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (from sentence-transformers) (1.4.2)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\rohan mukherjee\appdata\roaming\python\python312\site-packages (from sentence-transformers) (0.26.2)
# Requirement already satisfied: Pillow in c:\programdata\anaconda3\lib\site-packages (from sentence-transformers) (10.3.0)
# Requirement already satisfied: filelock in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.11.0)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: setuptools in c:\programdata\anaconda3\lib\site-packages (from torch>=1.11.0->sentence-transformers) (69.5.1)
# Requirement already satisfied: sympy==1.13.1 in c:\users\rohan mukherjee\appdata\roaming\python\python312\site-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\programdata\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2023.10.3)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\rohan mukherjee\appdata\roaming\python\python312\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\rohan mukherjee\appdata\roaming\python\python312\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.20.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn->sentence-transformers) (2.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\programdata\anaconda3\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.8.30)

# %%
import os
import json
import re
from typing import List, Tuple, Dict, Union
import pandas as pd
import torch
import numpy as np
import matplotlib.pyplot as plt

from wordvec_tests import (
    load_synonyms_data,
    Exercise1Runner,
    Exercise2Runner,
    Exercise3aRunner,
    Exercise3bRunner,
    Exercise4Runner,
    Exercise5Runner,
    Exercise6Runner
)

# %%
parent_dir = os.path.dirname(os.path.abspath("__file__"))
data_dir = os.path.join(parent_dir, "data")

# %% [markdown]
# ## Part 1: Geometry of Word Embeddings

# %% [markdown]
# We provide a helper class to access the glove vectors

# %%
######################################################
#  The following code is given to you. DO NOT MODIFY.
######################################################
class GloveEmbeddings:

    def __init__(self, path="embeddings/glove.6B/glove.6B.50d.txt"):
        self.path = path
        self.vec_size = int(re.search(r"\d+(?=d)", path).group(0))
        self.embeddings = {}
        self.load()

    def load(self):
        for line in open(self.path, "r", encoding="utf-8"):
            values = line.split()

            word_len = len(values) - self.vec_size

            word = " ".join(values[:word_len])
            vector_values = list(map(float, values[word_len:]))

            word = values[0]
            vector_values = list(map(float, values[-self.vec_size:]))
            vector = torch.tensor(vector_values, dtype=torch.float)
            self.embeddings[word] = vector

    def is_word_in_embeddings(self, word):
        return word in self.embeddings

    def get_vector(self, word):
        if not self.is_word_in_embeddings(word):
            return self.embeddings["unk"]
        return self.embeddings[word]

    # Use square operator to get the vector of a word
    def __getitem__(self, word):
        return self.get_vector(word)

# %%
######################################################
#  The following code is given to you. DO NOT MODIFY.
######################################################
glove_vectors = GloveEmbeddings(
    path=f"{data_dir}/embeddings/glove.6B/glove.6B.50d.txt"
)

# %% [markdown]
# You can simply use `glove_vectors[<word>]` to get the vector for a word

# %%
vector = glove_vectors["the"]
print(vector.shape)
print(vector)
# Out:
# torch.Size([50])
# tensor([ 4.1800e-01,  2.4968e-01, -4.1242e-01,  1.2170e-01,  3.4527e-01,
#         -4.4457e-02, -4.9688e-01, -1.7862e-01, -6.6023e-04, -6.5660e-01,
#          2.7843e-01, -1.4767e-01, -5.5677e-01,  1.4658e-01, -9.5095e-03,
#          1.1658e-02,  1.0204e-01, -1.2792e-01, -8.4430e-01, -1.2181e-01,
#         -1.6801e-02, -3.3279e-01, -1.5520e-01, -2.3131e-01, -1.9181e-01,
#         -1.8823e+00, -7.6746e-01,  9.9051e-02, -4.2125e-01, -1.9526e-01,
#          4.0071e+00, -1.8594e-01, -5.2287e-01, -3.1681e-01,  5.9213e-04,
#          7.4449e-03,  1.7778e-01, -1.5897e-01,  1.2041e-02, -5.4223e-02,
#         -2.9871e-01, -1.5749e-01, -3.4758e-01, -4.5637e-02, -4.4251e-01,
#          1.8785e-01,  2.7849e-03, -1.8411e-01, -1.1514e-01, -7.8581e-01])

# %%
print(glove_vectors["unk"].shape)
print(glove_vectors["the"].shape)
print(glove_vectors["king"].shape)
# Out:
# torch.Size([50])
# torch.Size([50])
# torch.Size([50])

# %% [markdown]
# Notice that we have a 50 dimensional vector for each word

# %% [markdown]
# ### Exercise 1: Synonyms (5 pts)
#
# This part is adapted from Dan Jurafsky's NLP class CS124 at Stanford.

# %%
######################################################
#  The following code is given to you. DO NOT MODIFY.
######################################################
dev_synonyms_df = load_synonyms_data("dev", data_dir=data_dir)
dev_synonyms_df.head()
# Out:
#          word                             choices true_answer
# 0    gullible  unrealistic,naive,complicated,wary       naive
# 1     counter                parry,agree,hold,run       parry
# 2      feeble        reinforced,weak,damage,break        weak
# 3  administer                give,steal,spray,box        give
# 4      betray          trust,inform,table,deceive     deceive

# %% [markdown]
# The task is to choose the synonym for a given word from a list of choices. We will use Glove embeddings to find the closest word in the embedding space.
#
# There are different metrics to obtain distance / similarity between two vectors in n-dimensional space. These include:
#
# 1. Euclidean Distance: $d(u, v)  = ||u - v||_2$
# 2. Manhattan Distance: $d(u, v) = ||u - v||_1$
# 3. Cosine Similarity: $s(u, v) = \frac{u \cdot v}{||u||_2 ||v||_2}$
#
# where $u$ and $v$ are vectors.
#
# You will implement a function `find_synonym` that for a word finds the closest synonym from a list of words. The method also receives a distance / similarity metric to use. The function should return the synonym and the value of the metric for the closest word.

# %%
def cosine_similarity(v1: torch.Tensor, v2: torch.Tensor) -> float:
    """
    Compute the cosine similarity between two vectors.

    Inputs:
    v1: torch.Tensor of shape (n,)
    v2: torch.Tensor of shape (n,)

    Returns:
    float: cosine similarity between v1 and v2
    """

    # YOUR CODE HERE
    if torch.norm(v1) == 0 or torch.norm(v2) == 0:
        return 0
    return ((v1 @ v2)/(torch.norm(v1) * torch.norm(v2))).item()


def euclidean_distance(v1: torch.Tensor, v2: torch.Tensor) -> float:
    """
    Compute the Euclidean distance between two vectors.

    Inputs:
    v1: torch.Tensor of shape (n,)
    v2: torch.Tensor of shape (n,)

    Returns:
    float: Euclidean distance between v1 and v2
    """
    # YOUR CODE HERE
    return torch.norm(v1-v2, p=2).item()


def manhattan_distance(v1: torch.Tensor, v2: torch.Tensor) -> float:
    """
    Compute the Manhattan distance between two vectors.

    Inputs:
    v1: torch.Tensor of shape (n,)
    v2: torch.Tensor of shape (n,)

    Returns:
    float: Manhattan distance between v1 and v2
    """

    # YOUR CODE HERE
    return torch.norm(v1-v2, p=1).item()


def find_synonym(
    word: str,
    choices: List[str],
    embeddings: GloveEmbeddings,
    metric: str = "cosine"
) -> Dict[str, Union[str, float]]:
    """
    Computes the synonym of `word` using Glove `embeddings`

    Inputs:
    - word: The word for which we want to find the synonym
    - choices: A list of words to choose from
    - embeddings: GloveEmbeddings object
    - metric: The distance metric to use. Can be one of "cosine", "euclidean", or "manhattan"
    """

    synonym_dict = {
        "synonym": None,
        "metric": None
    }

    # YOUR CODE HERE
    if metric == "manhattan":
        similarity = manhattan_distance
    elif metric == "euclidean":
        similarity = euclidean_distance
    else:
        similarity = cosine_similarity
    
    dists = [similarity(embeddings[word], embeddings[choice]) for choice in choices]
    
    if metric == "cosine":
        synonym_dict["synonym"] = choices[np.argmax(dists)]
    else:
        synonym_dict["synonym"] = choices[np.argmin(dists)]
    synonym_dict["metric"] = metric
    
    return synonym_dict

# %%
######################################################
#  The following code is given to you. DO NOT MODIFY.
######################################################
exercise1 = Exercise1Runner(
    find_synonym=find_synonym,
)

exercise1.evaluate(True) #Set False if you only want to see the final accuracies
# Out:
# Excercise 1: Synonyms
# -----------------
# Answering exercise 1 using cosine as the comparison metric...
# 1. What is a synonym for gullible?
#     a) unrealistic
#     b) naive
#     c) complicated
#     d) wary
# you answered: naive
#
# 2. What is a synonym for counter?
#     a) parry
#     b) agree
#     c) hold
#     d) run
# you answered: hold
#
# 3. What is a synonym for feeble?
#     a) reinforced
#     b) weak
#     c) damage
#     d) break
# you answered: weak
#
# 4. What is a synonym for administer?
#     a) give
#     b) steal
#     c) spray
#     d) box
# you answered: give
#
# 5. What is a synonym for betray?
#     a) trust
#     b) inform
#     c) table
#     d) deceive
# you answered: deceive
#
# 6. What is a synonym for scour?
#     a) search
#     b) allow
#     c) gaze
#     d) gather
# you answered: search
#
# 7. What is a synonym for clean?
#     a) bare
#     b) tidy
#     c) rummage
#     d) pop
# you answered: bare
#
# 8. What is a synonym for abscond?
#     a) escape
#     b) rally
#     c) relinquish
#     d) flash
# you answered: relinquish
#
# 9. What is a synonym for envelop?
#     a) uncover
#     b) dry
#     c) conceal
#     d) surround
# you answered: surround
#
# 10. What is a synonym for curb?
#     a) keep
#     b) find
#     c) limit
#     d) grow
# you answered: limit
#
# 11. What is a synonym for oblivious?
#     a) unaware
#     b) mindful
#     c) precarious
#     d) careful
# you answered: unaware
#
# 12. What is a synonym for corroborate?
#     a) condemn
#     b) grieve
#     c) delight
#     d) confirm
# you answered: confirm
#
# 13. What is a synonym for capricious?
#     a) stable
#     b) unaware
#     c) fickle
#     d) eager
# you answered: fickle
#
# 14. What is a synonym for imminent?
#     a) impending
#     b) possible
#     c) moderate
#     d) unlikely
# you answered: impending
#
# 15. What is a synonym for lucrative?
#     a) honorable
#     b) profitable
#     c) exciting
#     d) predictable
# you answered: profitable
#
# 16. What is a synonym for languish?
#     a) work
#     b) avoid
#     c) attempt
#     d) suffer
# you answered: suffer
#
# 17. What is a synonym for incoherent?
#     a) unclear
#     b) quiet
#     c) wise
#     d) unfeeling
# you answered: unfeeling
#
# 18. What is a synonym for industrious?
#     a) energetic
#     b) prompt
#     c) diligent
#     d) headstrong
# you answered: diligent
#
# 19. What is a synonym for paucity?
#     a) envy
#     b) greed
#     c) shortage
#     d) presence
# you answered: shortage
#
# 20. What is a synonym for ambush?
#     a) surprise
#     b) warn
#     c) treat
#     d) announce
# you answered: surprise
#
# 21. What is a synonym for propose?
#     a) suggest
#     b) doubt
#     c) strive
#     d) write
# you answered: suggest
#
# 22. What is a synonym for vivid?
#     a) bright
#     b) dull
#     c) visible
#     d) loud
# you answered: bright
#
# 23. What is a synonym for keen?
#     a) visible
#     b) omnipotent
#     c) metal
#     d) sharp
# you answered: sharp
#
# 24. What is a synonym for bestow?
#     a) grant
#     b) cost
#     c) wipe
#     d) rise
# you answered: grant
#
# 25. What is a synonym for cogitate?
#     a) mirror
#     b) contemplate
#     c) discuss
#     d) sleep
# you answered: contemplate
#
# 26. What is a synonym for amble?
#     a) escape
#     b) ascend
#     c) groom
#     d) stroll
# you answered: stroll
#
# 27. What is a synonym for trajectory?
#     a) goal
#     b) orbit
#     c) cut
#     d) angle
# you answered: orbit
#
# 28. What is a synonym for annex?
#     a) conquer
#     b) limit
#     c) jump
#     d) hide
# you answered: conquer
#
# 29. What is a synonym for capitulate?
#     a) defeat
#     b) concede
#     c) raise
#     d) climb
# you answered: concede
#
# 30. What is a synonym for sanguine?
#     a) pessimistic
#     b) unsure
#     c) sad
#     d) positive
# you answered: pessimistic
#
# Answering exercise 1 using euclidean as the comparison metric...
# 1. What is a synonym for gullible?
#     a) unrealistic
#     b) naive
#     c) complicated
#     d) wary
# you answered: naive
#
# 2. What is a synonym for counter?
#     a) parry
#     b) agree
#     c) hold
#     d) run
# you answered: hold
#
# 3. What is a synonym for feeble?
#     a) reinforced
#     b) weak
#     c) damage
#     d) break
# you answered: weak
#
# 4. What is a synonym for administer?
#     a) give
#     b) steal
#     c) spray
#     d) box
# you answered: give
#
# 5. What is a synonym for betray?
#     a) trust
#     b) inform
#     c) table
#     d) deceive
# you answered: deceive
#
# 6. What is a synonym for scour?
#     a) search
#     b) allow
#     c) gaze
#     d) gather
# you answered: search
#
# 7. What is a synonym for clean?
#     a) bare
#     b) tidy
#     c) rummage
#     d) pop
# you answered: bare
#
# 8. What is a synonym for abscond?
#     a) escape
#     b) rally
#     c) relinquish
#     d) flash
# you answered: relinquish
#
# 9. What is a synonym for envelop?
#     a) uncover
#     b) dry
#     c) conceal
#     d) surround
# you answered: surround
#
# 10. What is a synonym for curb?
#     a) keep
#     b) find
#     c) limit
#     d) grow
# you answered: limit
#
# 11. What is a synonym for oblivious?
#     a) unaware
#     b) mindful
#     c) precarious
#     d) careful
# you answered: unaware
#
# 12. What is a synonym for corroborate?
#     a) condemn
#     b) grieve
#     c) delight
#     d) confirm
# you answered: confirm
#
# 13. What is a synonym for capricious?
#     a) stable
#     b) unaware
#     c) fickle
#     d) eager
# you answered: fickle
#
# 14. What is a synonym for imminent?
#     a) impending
#     b) possible
#     c) moderate
#     d) unlikely
# you answered: impending
#
# 15. What is a synonym for lucrative?
#     a) honorable
#     b) profitable
#     c) exciting
#     d) predictable
# you answered: profitable
#
# 16. What is a synonym for languish?
#     a) work
#     b) avoid
#     c) attempt
#     d) suffer
# you answered: avoid
#
# 17. What is a synonym for incoherent?
#     a) unclear
#     b) quiet
#     c) wise
#     d) unfeeling
# you answered: unfeeling
#
# 18. What is a synonym for industrious?
#     a) energetic
#     b) prompt
#     c) diligent
#     d) headstrong
# you answered: headstrong
#
# 19. What is a synonym for paucity?
#     a) envy
#     b) greed
#     c) shortage
#     d) presence
# you answered: envy
#
# 20. What is a synonym for ambush?
#     a) surprise
#     b) warn
#     c) treat
#     d) announce
# you answered: surprise
#
# 21. What is a synonym for propose?
#     a) suggest
#     b) doubt
#     c) strive
#     d) write
# you answered: suggest
#
# 22. What is a synonym for vivid?
#     a) bright
#     b) dull
#     c) visible
#     d) loud
# you answered: bright
#
# 23. What is a synonym for keen?
#     a) visible
#     b) omnipotent
#     c) metal
#     d) sharp
# you answered: sharp
#
# 24. What is a synonym for bestow?
#     a) grant
#     b) cost
#     c) wipe
#     d) rise
# you answered: grant
#
# 25. What is a synonym for cogitate?
#     a) mirror
#     b) contemplate
#     c) discuss
#     d) sleep
# you answered: contemplate
#
# 26. What is a synonym for amble?
#     a) escape
#     b) ascend
#     c) groom
#     d) stroll
# you answered: stroll
#
# 27. What is a synonym for trajectory?
#     a) goal
#     b) orbit
#     c) cut
#     d) angle
# you answered: angle
#
# 28. What is a synonym for annex?
#     a) conquer
#     b) limit
#     c) jump
#     d) hide
# you answered: hide
#
# 29. What is a synonym for capitulate?
#     a) defeat
#     b) concede
#     c) raise
#     d) climb
# you answered: concede
#
# 30. What is a synonym for sanguine?
#     a) pessimistic
#     b) unsure
#     c) sad
#     d) positive
# you answered: pessimistic
#
# Answering exercise 1 using manhattan as the comparison metric...
# 1. What is a synonym for gullible?
#     a) unrealistic
#     b) naive
#     c) complicated
#     d) wary
# you answered: naive
#
# 2. What is a synonym for counter?
#     a) parry
#     b) agree
#     c) hold
#     d) run
# you answered: hold
#
# 3. What is a synonym for feeble?
#     a) reinforced
#     b) weak
#     c) damage
#     d) break
# you answered: weak
#
# 4. What is a synonym for administer?
#     a) give
#     b) steal
#     c) spray
#     d) box
# you answered: give
#
# 5. What is a synonym for betray?
#     a) trust
#     b) inform
#     c) table
#     d) deceive
# you answered: deceive
#
# 6. What is a synonym for scour?
#     a) search
#     b) allow
#     c) gaze
#     d) gather
# you answered: search
#
# 7. What is a synonym for clean?
#     a) bare
#     b) tidy
#     c) rummage
#     d) pop
# you answered: tidy
#
# 8. What is a synonym for abscond?
#     a) escape
#     b) rally
#     c) relinquish
#     d) flash
# you answered: relinquish
#
# 9. What is a synonym for envelop?
#     a) uncover
#     b) dry
#     c) conceal
#     d) surround
# you answered: surround
#
# 10. What is a synonym for curb?
#     a) keep
#     b) find
#     c) limit
#     d) grow
# you answered: limit
#
# 11. What is a synonym for oblivious?
#     a) unaware
#     b) mindful
#     c) precarious
#     d) careful
# you answered: mindful
#
# 12. What is a synonym for corroborate?
#     a) condemn
#     b) grieve
#     c) delight
#     d) confirm
# you answered: confirm
#
# 13. What is a synonym for capricious?
#     a) stable
#     b) unaware
#     c) fickle
#     d) eager
# you answered: fickle
#
# 14. What is a synonym for imminent?
#     a) impending
#     b) possible
#     c) moderate
#     d) unlikely
# you answered: impending
#
# 15. What is a synonym for lucrative?
#     a) honorable
#     b) profitable
#     c) exciting
#     d) predictable
# you answered: profitable
#
# 16. What is a synonym for languish?
#     a) work
#     b) avoid
#     c) attempt
#     d) suffer
# you answered: avoid
#
# 17. What is a synonym for incoherent?
#     a) unclear
#     b) quiet
#     c) wise
#     d) unfeeling
# you answered: unfeeling
#
# 18. What is a synonym for industrious?
#     a) energetic
#     b) prompt
#     c) diligent
#     d) headstrong
# you answered: headstrong
#
# 19. What is a synonym for paucity?
#     a) envy
#     b) greed
#     c) shortage
#     d) presence
# you answered: presence
#
# 20. What is a synonym for ambush?
#     a) surprise
#     b) warn
#     c) treat
#     d) announce
# you answered: surprise
#
# 21. What is a synonym for propose?
#     a) suggest
#     b) doubt
#     c) strive
#     d) write
# you answered: suggest
#
# 22. What is a synonym for vivid?
#     a) bright
#     b) dull
#     c) visible
#     d) loud
# you answered: bright
#
# 23. What is a synonym for keen?
#     a) visible
#     b) omnipotent
#     c) metal
#     d) sharp
# you answered: sharp
#
# 24. What is a synonym for bestow?
#     a) grant
#     b) cost
#     c) wipe
#     d) rise
# you answered: grant
#
# 25. What is a synonym for cogitate?
#     a) mirror
#     b) contemplate
#     c) discuss
#     d) sleep
# you answered: contemplate
#
# 26. What is a synonym for amble?
#     a) escape
#     b) ascend
#     c) groom
#     d) stroll
# you answered: stroll
#
# 27. What is a synonym for trajectory?
#     a) goal
#     b) orbit
#     c) cut
#     d) angle
# you answered: angle
#
# 28. What is a synonym for annex?
#     a) conquer
#     b) limit
#     c) jump
#     d) hide
# you answered: conquer
#
# 29. What is a synonym for capitulate?
#     a) defeat
#     b) concede
#     c) raise
#     d) climb
# you answered: concede
#
# 30. What is a synonym for sanguine?
#     a) pessimistic
#     b) unsure
#     c) sad
#     d) positive
# you answered: pessimistic
#
# accuracy using cosine similarity : 0.83333
# accuracy using euclidean distance : 0.66667
# accuracy using manhattan distance : 0.70000

# %% [markdown]
# You should expect the dev accuracy to be 83% with cosine similarity metric, 67% with euclidean distance and 70% with manhattan distance.

# %% [markdown]
# ### Exercise 2: Analogies (3 pts)
#
# In this exercise you will use the Linear Representation Hypothesis (check handout to learn about it) to solve the analogy task:
#
# man is to king as woman is to ______ ?
#     a) princess
#     b) queen
#     c) wife
#     d) ruler
#
# The task is to find the most appropriate word out of the 4 choices that completes the analogy.
#
# This part is adapted from Dan Jurafsky's NLP class CS124 at Stanford.

# %%
def find_analogy_word(
    a: str,
    b: str,
    aa: str,
    choices: List[str],
    embeddings: GloveEmbeddings,
):

    """
    Given the analogy relation a is to aa as b is to ____, find the word from choices that completes the analogy.
    e.g. man is to king as woman is to ____?
    a) princess
    b) queen
    c) wife
    d) ruler

    Note: Use cosine similarity as the metric for this function.

    Inputs:
    - a, b, aa: The words in the analogy relation
    - choices: A list of words to choose from
    - embeddings: GloveEmbeddings object

    Returns:
     str: The word from choices that best completes the analogy
    """
    
    # idea: bb - b = aa - a => bb = b + (aa-a)
    # b + the thing that turns a into aa.

    # YOUR CODE HERE
    angles = [
        cosine_similarity(embeddings[choice] - embeddings[b], embeddings[aa]-embeddings[a]) 
        for choice in choices
    ]
    answer = choices[np.argmax(angles)]

    return answer

# %%
######################################################
#  The following code is given to you. DO NOT MODIFY.
######################################################
exercise2 = Exercise2Runner(find_analogy_word=find_analogy_word)
exercise2.evaluate(True) #Set False if you only want to see the final accuracies
# Out:
# Excercise 2: Analogies
# -----------------
# Answering exercise 2...
# 1. king is to queen as man is to ?
#     a) wife
#     b) woman
#     c) head
#     d) ruler
# You answered: woman
#
# 2. dog is to puppy as cat is to ?
#     a) kitten
#     b) puppy
#     c) feline
#     d) mouse
# You answered: feline
#
# 3. father is to son as mother is to ?
#     a) girl
#     b) wife
#     c) daughter
#     d) queen
# You answered: daughter
#
# 4. listen is to hear as look is to ?
#     a) taste
#     b) see
#     c) feel
#     d) think
# You answered: see
#
# 5. doctor is to hospital as lawyer is to ?
#     a) court
#     b) restaurant
#     c) museum
#     d) library
# You answered: court
#
# 6. good is to great as bad is to ?
#     a) better
#     b) worse
#     c) okay
#     d) sad
# You answered: worse
#
# 7. stove is to kitchen as tub is to ?
#     a) closet
#     b) bedroom
#     c) bathroom
#     d) pantry
# You answered: bathroom
#
# 8. spoon is to soup as fork is to ?
#     a) sorbet
#     b) steak
#     c) banana
#     d) berry
# You answered: berry
#
# 9. phone is to talk as television is to ?
#     a) hear
#     b) watch
#     c) sleep
#     d) read
# You answered: watch
#
# 10. carrot is to orange as banana is to ?
#     a) green
#     b) yellow
#     c) red
#     d) black
# You answered: black
#
# 11. sleep is to bed as sit is to ?
#     a) dresser
#     b) closet
#     c) chair
#     d) desk
# You answered: chair
#
# 12. rock is to hard as feather is to ?
#     a) flat
#     b) limp
#     c) rough
#     d) soft
# You answered: soft
#
# 13. bowl is to soup as plate is to ?
#     a) sandwich
#     b) banana
#     c) yogurt
#     d) jam
# You answered: banana
#
# 14. bird is to eagle as snake is to ?
#     a) reptile
#     b) cobra
#     c) poison
#     d) skin
# You answered: cobra
#
# 15. attach is to join as surrender is to ?
#     a) forfeit
#     b) explain
#     c) frighten
#     d) risk
# You answered: forfeit
#
# 16. heat is to cold as tranquility is to ?
#     a) government
#     b) control
#     c) island
#     d) commotion
# You answered: commotion
#
# 17. wet is to dry as dull is to ?
#     a) dreary
#     b) unfailing
#     c) spirited
#     d) long
# You answered: spirited
#
# 18. meat is to carnivore as plant is to ?
#     a) omnivore
#     b) herbivore
#     c) canine
#     d) human
# You answered: herbivore
#
# 19. zebra is to animal as dessert is to ?
#     a) color
#     b) shape
#     c) food
#     d) country
# You answered: food
#
# 20. hideous is to pretty as nice is to ?
#     a) kind
#     b) safe
#     c) terrible
#     d) mean
# You answered: safe
#
# 21. one is to single as two is to ?
#     a) triple
#     b) double
#     c) multiple
#     d) three
# You answered: three
#
# 22. fox is to foxes as goose is to ?
#     a) cow
#     b) duck
#     c) geese
#     d) birds
# You answered: geese
#
# 23. seed is to plant as egg is to ?
#     a) mouse
#     b) tree
#     c) bird
#     d) oyster
# You answered: oyster
#
# 24. scissor is to cut as needle is to ?
#     a) point
#     b) stab
#     c) sew
#     d) repair
# You answered: point
#
# 25. hungry is to full as good is to ?
#     a) kind
#     b) evil
#     c) lovely
#     d) neutral
# You answered: kind
#
# accuracy using analogy questions : 0.64000

# %% [markdown]
# You should see an accuracy of 64%

# %%
def test_other_concepts():
    # Relation: Synonyms
    # car is to automobile as bike is to _____ ?
    # a) horse
    # b) bicycle
    # c) house
    # d) oranges
    
    print(find_analogy_word("car", "automobile", "bike", ["horse", "bicycle", "house", "oranges"], glove_vectors))
    
    # house is to residence as cow is to _____ ?
    # a) bus
    # b) horse
    # c) air
    # d) bull
    
    print(find_analogy_word("house", "residence", "cow", ["bus", "horse", "air", "bull"], glove_vectors))
    
    # Relation: Antonyms
    # happy is to sad as good is to ______ ?
    # a) bad
    # b) horse
    # c) water
    # d) cow
    print(find_analogy_word("happy", "sad", "good", ["bad", "horse", "water", "cow"], glove_vectors))
    
    # big is to small as fast is to ______ ?
    # a) slow
    # b) horse
    # c) water
    # d) feline
    print(find_analogy_word("big", "small", "fast", ["slow", "horse", "water", "feline"], glove_vectors))
    
    # Relation: basic/subordinate
    # car is to vehicle as apple is to ______ ?
    # a) fruit
    # b) horse
    # c) water
    # d) air
    print(find_analogy_word("car", "vehicle", "apple", ["fruit", "horse", "water", "air"], glove_vectors))
    
    # horse is to animal as chair is to ______ ?
    # a) fruit
    # b) furniture
    # c) water
    # d) air
    print(find_analogy_word("horse", "animal", "chair", ["fruit", "furniture", "water", "air"], glove_vectors))

test_other_concepts()
# Out:
# bicycle
# bull
# bad
# slow
# fruit
# furniture

# %% [markdown]
# ### Exercise 3: Bias in Word Embeddings (10 pts)
#
# We will now implement the Word Embedding Association Test (WEAT) to identify biases in word embeddings. Check the handout for a detailed explanation of the test. You will start by implementing the *Effect Size* metric by implementing the functions:
#
# - `word_association_wth_attribute`
# - `weat_effect_size`
#
# `word_association_wth_attribute` computes $s(w, A, B)$ for a given word $w$ and attributes $A$ and $B$, i.e. the association of the word with the attributes. Recall that this is given by:
#
# $$s(w, A, B) = \text{mean}_{a \in A}\text{cos}(\vec{w}, \vec{a}) - \text{mean}_{b \in B} (\vec{w}, \vec{b})$$
#
# The effect size is then given as:
#
# $$\text{effect-size} = \frac{\text{mean}_{x \in X} s(x, A, B) - \text{mean}_{y \in Y} s(y, A, B)}{\text{std-dev}_{w \in X \cup Y} s(w, A, B)}$$

# %%
######################################################
#  The following code is given to you. DO NOT MODIFY.
######################################################
with open(f"{data_dir}/weat/weat.json", "r") as f:
    weat_data = json.load(f)

weat_data.keys()
# Out:
# dict_keys(['Careers_Female_Male', 'EuropeanAmerican_AfricanAmerican_Pleasant_Unpleasant', 'EuropeanAmerican_AfricanAmerican_Pleasant_Unpleasant_2', 'Flowers_Insects_Pleasant_Unpleasant', 'Male_Female_Career_Family', 'Math_Arts_Male_Female', 'MusicalInstruments_Weapons_Pleasant_Unpleasant', 'Names_Female_Male', 'Science_Arts_Male_Female'])

# %%
def word_association_wth_attribute(
    word: str,
    A: List[str],
    B: List[str],
    embeddings: GloveEmbeddings,
) -> float:

    """
    Finds the association of a word in the emedding space with the two sets of attribute words.
    E.g. Given the word "rose", a set of pleasant words A and unpleasant words B, the function finds if its degree of association to A vs B.

    Inputs:
    - word: The word for which we want to find the association
    - A: List of words representing the first set of attributes
    - B: List of words representing the second set of attributes

    Returns:
    float: The association of the word with the two sets of attributes
    """

    return np.mean([cosine_similarity(embeddings[word], embeddings[a]) for a in A]) - np.mean([cosine_similarity(embeddings[word], embeddings[b]) for b in B])

def weat_effect_size(
    X: List[str],
    Y: List[str],
    A: List[str],
    B: List[str],
    embeddings: GloveEmbeddings,
) -> float:
    """
    Compute the effect size of the WEAT test.

    Inputs:
    - X: List of target words for which we want to find the association.
    - Y: List of target words for which we want to find the association.
    - A: List of words representing the first set of attributes
    - B: List of words representing the second set of attributes
    - embeddings: GloveEmbeddings object
    """
    effect_size = ((np.mean([word_association_wth_attribute(x, A, B, embeddings) for x in X]) - np.mean([word_association_wth_attribute(y, A, B, embeddings) for y in Y])) / 
                   np.std([word_association_wth_attribute(w, A, B, embeddings) for w in X + Y]))

    return effect_size

# %%
######################################################
#  The following code is given to you. DO NOT MODIFY.
######################################################
exercise3 = Exercise3aRunner(
    weat_effect_size=weat_effect_size,
)
exercise3.evaluate_effect_size(
    False
)  # Set False if you only want to see the final effect sizes
# Out:
# Excercise 3a: WEAT Effect Size
# -----------------
# Effect size for Flowers-Insects Pleasant Unpleasant case: 1.08876
# Effect size for MusicalInstruments-Weapons Pleasant Unpleasant case: 1.55964
# Effect size for EuropeanAmerican AfricanAmerican_Pleasant_Unpleasant case: 1.00901
# Effect size for Male_Female Career_Family case : 1.76379
# Effect size for Math_Art Male_Female case : 1.54417

# %% [markdown]
# You should observe the following numbers:
#
#
# Effect size for Flowers-Insects Pleasant Unpleasant case: 1.07782
#
# Effect size for MusicalInstruments-Weapons Pleasant Unpleasant case: 1.54396
#
# Effect size for EuropeanAmerican AfricanAmerican_Pleasant_Unpleasant case: 1.00395
#
# Effect size for Male_Female Career_Family case : 1.70778
#
# Effect size for Math_Art Male_Female case : 1.49513

# %% [markdown]
# We will now check how statistically significant are these effect sizes. You will implement the function `target_words_diff_association_wth_attribute` which calculates the value of the test statistic: $s(X, Y, A, B)$. Recall this is given by:
#
# $$    s(X, Y, A, B) = \sum_{x \in X} s(x, A, B) - \sum_{y \in Y} s(y, A, B)$$
#
# We then use this function to calculate the p-value of the permutation test. We provide you the implementation of the function `weat_p_value`. We recommend you to go through the code to understand how the p-value is calculated, even though you are not supposed to implement it.

# %%
def target_words_diff_association_wth_attribute(
    X: List[str],
    Y: List[str],
    A: List[str],
    B: List[str],
    embeddings: GloveEmbeddings,
) -> float:
    """
    Finds the differential association of words in X with the attribute sets A and B vs the words in Y with the attribute sets A and B.

    E.g. X can be flower names and Y can be insect names.A can be pleasant words and B can be unpleasant words.
    The function measures the difference in total association of flower names and insect names with sets A and B.


    Inputs:
    - words: List of target words for which we want to find the association.
    - A: List of words representing the first set of attributes
    - B: List of words representing the second set of attributes
    - embeddings: GloveEmbeddings object
    """

    return np.sum([word_association_wth_attribute(x, A, B, embeddings) for x in X]) - np.sum([word_association_wth_attribute(y, A, B, embeddings) for y in Y])


######################################################
#  The following code is given to you. DO NOT MODIFY.
######################################################
def weat_p_value(
    X: List[str],
    Y: List[str],
    A: List[str],
    B: List[str],
    embeddings: GloveEmbeddings,
    max_permutations: int = 1000,
) -> Tuple[float, float]:
    """
    Compute the p-values of the WEAT test.

    Inputs:
    - X: List of target words for which we want to find the association.
    - Y: List of target words for which we want to find the association.
    - A: List of words representing the first set of attributes
    - B: List of words representing the second set of attributes
    - embeddings: GloveEmbeddings object
    """

    import numpy as np
    diff_association = target_words_diff_association_wth_attribute(X, Y, A, B, embeddings)

    target_words = X + Y
    # print(len(target_words))

    partition_idx = np.zeros(len(target_words))
    partition_idx[:len(target_words) // 2] = 1

    partition_dff_associations = []
    for _ in range(max_permutations):
        if len(partition_dff_associations) >= max_permutations:
            break
        i = np.random.permutation(partition_idx)
        X_perm = [target_words[j] for j in range(len(target_words)) if i[j] == 1]
        Y_perm = [target_words[j] for j in range(len(target_words)) if i[j] == 0]
        partition_dff_associations.append(
            target_words_diff_association_wth_attribute(
                X_perm, Y_perm, A, B, embeddings
            )
        )
    return np.sum(np.array(partition_dff_associations) > diff_association) / len(
        partition_dff_associations
    )

# %%
######################################################
#  The following code is given to you. DO NOT MODIFY.
######################################################
exercise3b = Exercise3bRunner(
    weat_p_value=weat_p_value,
)

exercise3b.evaluate(True) #Set False if you only want to see the final p-values # This might take a while to run (1 minute during our testing)
# Out:
# Excercise 3b: WEAT P-Value
# -----------------
# Answering exercise 3 using EuropeanAmerican_AfricanAmerican_Pleasant_Unpleasant as the dataset...
# Target Group X: ['adam', 'chip', 'harry', 'josh', 'roger', 'alan', 'frank', 'ian', 'justin', 'ryan', 'andrew', 'fred', 'jack', 'matthew', 'stephen', 'brad', 'greg', 'jed', 'paul', 'todd', 'brandon', 'hank', 'jonathan', 'peter', 'wilbur', 'amanda', 'courtney', 'heather', 'melanie', 'sara', 'amber', 'crystal', 'katie', 'meredith', 'shannon', 'betsy', 'donna', 'kristin', 'nancy', 'stephanie', 'bobbie-sue', 'ellen', 'lauren', 'peggy', 'sue-ellen', 'colleen', 'emily', 'megan', 'rachel', 'wendy']
# Target Group Y: ['alonzo', 'jamel', 'lerone', 'percell', 'theo', 'alphonse', 'jerome', 'leroy', 'rasaan', 'torrance', 'darnell', 'lamar', 'lionel', 'rashaun', 'tvree', 'deion', 'lamont', 'malik', 'terrence', 'tyrone', 'everol', 'lavon', 'marcellus', 'terryl', 'wardell', 'aiesha', 'lashelle', 'nichelle', 'shereen', 'temeka', 'ebony', 'latisha', 'shaniqua', 'tameisha', 'teretha', 'jasmine', 'latonya', 'shanise', 'tanisha', 'tia', 'lakisha', 'latoya', 'sharise', 'tashika', 'yolanda', 'lashandra', 'malika', 'shavonn', 'tawanda', 'yvette']
# Attribute Group A: ['caress', 'freedom', 'health', 'love', 'peace', 'cheer', 'friend', 'heaven', 'loyal', 'pleasure', 'diamond', 'gentle', 'honest', 'lucky', 'rainbow', 'diploma', 'gift', 'honor', 'miracle', 'sunrise', 'family', 'happy', 'laughter', 'paradise', 'vacation']
# Attribute Group B: ['abuse', 'crash', 'filth', 'murder', 'sickness', 'accident', 'death', 'grief', 'poison', 'stink', 'assault', 'disaster', 'hatred', 'pollute', 'tragedy', 'bomb', 'divorce', 'jail', 'poverty', 'ugly', 'cancer', 'evil', 'kill', 'rotten', 'vomit']
#
# Answering exercise 3 using Male_Female_Career_Family as the dataset...
# Target Group X: ['john', 'paul', 'mike', 'kevin', 'steve', 'greg', 'jeff', 'bill']
# Target Group Y: ['amy', 'joan', 'lisa', 'sarah', 'diana', 'kate', 'ann', 'donna']
# Attribute Group A: ['executive', 'management', 'professional', 'corporation', 'salary', 'office', 'business', 'career']
# Attribute Group B: ['home', 'parents', 'children', 'family', 'cousins', 'marriage', 'wedding', 'relatives']
#
# Answering exercise 3 using Math_Arts_Male_Female as the dataset...
# Target Group X: ['math', 'algebra', 'geometry', 'calculus', 'equations', 'computation', 'numbers', 'addition']
# Target Group Y: ['poetry', 'art', 'dance', 'literature', 'novel', 'symphony', 'drama', 'sculpture']
# Attribute Group A: ['male', 'man', 'boy', 'brother', 'he', 'him', 'his', 'son']
# Attribute Group B: ['female', 'woman', 'girl', 'sister', 'she', 'her', 'hers', 'daughter']
#
# P-value for EuropeanAmerican AfricanAmerican_Pleasant_Unpleasant case: 0.00000
# P-value for Male Female Career Family case : 0.00000
# P-value for Math_Art Male_Female case 0.00000

# %% [markdown]
# You should see p-values as 0.0 for all the cases (Note that this is approximate since we are not exaustively considering all the permutations and only considering 1000 random permutations. But the actual p-value should be very close to 0.)

# %% [markdown]
# ### Useful pointers for write up question 3 in 1.1.3 of handout:
#
# Glove embeddings of size {{vec_dim}} (e.g. 50) trained on {{num_tokens}} (e.g. 6B) can be loaded as:
#
# ```
# glove_vectors = load_glove_vectors(
#     f"{data_dir}/embeddings/glove.6B/glove.WEAT.6B.50d.txt",
# )
# ```
#
# where you change the values of 6B and 50 based on the size of the embeddings and number of tokens used in training.
#
# To load weat data of a particular category, you can use the following code:
#
# ```
# category = "Flowers_Insects_Pleasant_Unpleasant" # Change this to the category you want to load
#
# weat_category_data = weat_data[category]
#
# X = weat_category_data["X"]
# Y = weat_category_data["Y"]
# A = weat_category_data["A"]
# B = weat_category_data["B"]
# ```

# %%
# Effect of scale on WEAT Effect Sizes

names = ["EuropeanAmerican_AfricanAmerican_Pleasant_Unpleasant", "Flowers_Insects_Pleasant_Unpleasant", "Male_Female_Career_Family", "Math_Arts_Male_Female", "MusicalInstruments_Weapons_Pleasant_Unpleasant"]

def get_weat_effect_size(weat_data, glove_embeddings):
    X, Y, A, B = weat_data[weat_data["X_key"]], weat_data[weat_data["Y_key"]], weat_data[weat_data["A_key"]], weat_data[weat_data["B_key"]]

    effect_size = weat_effect_size(X, Y, A, B, glove_embeddings)
    return effect_size

def get_effect_sizes_6b_tokens():
    vector_sizes = [50, 100, 200, 300]
    effect_sizes_6b_tokens = [[] for _ in names]
    
    for vector_size in vector_sizes:
        glove_embeddings = GloveEmbeddings(
            path=f"{data_dir}/embeddings/glove.6B/glove.WEAT.6B.{vector_size}d.txt"
        )
        
        for i, name in enumerate(names):
            data = weat_data[name]
            effect_sizes_6b_tokens[i].append(get_weat_effect_size(data, glove_embeddings))
            
    plt.figure()
    
    for name, data in zip(names, effect_sizes_6b_tokens):
        plt.plot(vector_sizes, data, label=name)
        
    plt.title("Effect sizes vs vector size for 6B tokens")
    plt.xlabel("Vector size")
    plt.ylabel("Effect size")
    plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
    plt.show()

def get_effect_sizes_300d_vectors():
    num_tokens = ["6B", "42B", "840B"]
    effect_sizes_300d_vectors = [[] for _ in names]
    
    for num_token in num_tokens:
        glove_embeddings = GloveEmbeddings(
            path=f"{data_dir}/embeddings/glove.{num_token}/glove.WEAT.{num_token}.300d.txt"
        )
        
        for i, name in enumerate(names):
            data = weat_data[name]
            effect_sizes_300d_vectors[i].append(get_weat_effect_size(data, glove_embeddings))
        
    plt.figure()
    
    for name, data in zip(names, effect_sizes_300d_vectors):
        plt.plot(num_tokens, data, label=name)
        
    plt.title("Effect sizes vs num tokens for 300d vectors")
    plt.xlabel("Number of tokens (billions)")
    plt.ylabel("Effect size")
    plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
    plt.show()

get_effect_sizes_6b_tokens()
get_effect_sizes_300d_vectors()

# %% [markdown]
# ## Part 2: From Word Embeddings to Sentence Level Embeddings

# %% [markdown]
# ### Exercise 3.1 Sentence Similarity (3 pts)
#
# *This part is adapted from Dan Jurafsky's NLP class CS124 at Stanford.*
#
# In this exercise you will be building sentence level representations using word embeddings and then use them to find similarity between two sentences. In particular your goal is to answer questions of the form:
#
# ```
#     True/False: the following two sentences are semantically similar:
#       1. he later learned that the incident was caused by the concorde's sonic boom
#       2. he later found out the alarming incident had been caused by concorde's powerful sonic boom
# ```
#
# To build sentence level representations, you will use the following approaches:
#
# * **Simple sum**: Simply take the sum of word embeddings of all words in the sentence
# * **Sum with POS weighting**: Take a weighted sum of the individual word vectors, where the weight of each word depends on the part of speech tag (POS) of the word.
#
# Specifically, you will implement the following functions:
# * **get_sentence_embedding()**: given a sentence (string), return the sentence embedding (vector). The function also takes in the parameter `use_POS`:
#     * if `use_POS` is false (regular case), leverage method 1 above - simply the sum of the word embeddings for each word in the sentence (ignoring words that don’t appear in our vocabulary).
#     * if `use_POS` is true, leverage method 2 - use a weighted sum, where we weight each word by a scalar that depends on its part of speech tag.
# * **get_sentence_similarity()**: given two sentences, find the cosine similarity between their corresponding sentence embeddings.
#
# Helpful hints:
#
# * Lowercase all words in the sentence before you look them up in the embeddings. The Glove embeddings that we are using have all words in lowercase.
#
# * We’ve given you a map `POS_weights` that maps part of speech tags to their associated weight. For example, `POS_weights['NN'] = 0.8` (where NN is the POS tag for noun).
# * You may skip words that either (1) are not in our embeddings or (2) have a POS tag that is not in `POS_weights` . To check if a word is not in our embeddings, you can use the following code snippet:
#
# ```
#     if glove_vectors.is_word_in_embeddings(word):
#         # word is in embeddings
#     else:
#         # word is not in embeddings
# ```
# * To get a list of all the words in the sentence, use nltk's word_tokenize function.
#
#   ```
#   >>> sentence = "this is a sentence"
#   >>> word_tokens = word_tokenize(sentence)
#   >>> word_tokens
#   ['this', 'is', 'a', 'sentence']
#   ```
#
#   * To get the POS tags for each word in a sentence, you can use nltk.pos_tag. To use it, you provide a list of words in a sentence, and it returns a list of tuples, where the first element is the word and the second is its corresponding POS tag. **For this PA, make sure that you pass in the entire sentence to a single call to nltk.pos_tag; do not call  nltk.pos_tag separately on each word in the sentence.** This is because some words can be multiple parts of speech (for example, "back" can be a noun or a verb). Passing in the entire sentence allows for more context to figure out what POS tag a word should have.
#
# ```
#     >>> tagged_words = nltk.pos_tag(word_tokens)
#     >>> tagged_words
#     [('this', 'DT'), ('is', 'VBZ'), ('a', 'DT'), ('sentence', 'NN')]`
# ```

# %%
# You will use nltk for tokenizing and tagging!
import nltk

# %%
######################################################
#  The following code is given to you. DO NOT MODIFY.
######################################################
# Run this cell to download the nltk tagger
nltk.download("punkt")
nltk.download('averaged_perceptron_tagger')
nltk.download("averaged_perceptron_tagger_eng")
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Rohan
# [nltk_data]     Mukherjee\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Rohan Mukherjee\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Rohan Mukherjee\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
######################################################
#  The following code is given to you. DO NOT MODIFY.
######################################################
# Run this cell to load POS Weights
with open(f"{data_dir}/pos_weights.txt", "r") as f:
    pos_weights = f.read().split("\n")
    pos_weights = {line.split()[0]: float(line.split()[1]) for line in pos_weights}
print(pos_weights)
# Out:
# {'CC': 0.7, 'CD': 0.8, 'DT': 0.7, 'EX': 0.7, 'FW': 0.7, 'IN': 0.7, 'JJ': 0.7, 'JJR': 0.7, 'JJS': 0.8, 'LS': 0.7, 'MD': 1.2, 'NN': 0.8, 'NNS': 1.0, 'NNP': 0.8, 'NNPS': 0.8, 'PDT': 0.7, 'POS': 0.7, 'PRP': 0.7, 'PRP$': 0.7, 'RB': 1.3, 'RBR': 1.2, 'RBS': 1.0, 'RP': 1.2, 'SYM': 0.7, 'TO': 0.8, 'UH': 0.7, 'VB': 1.2, 'VBD': 1.2, 'VBG': 1.1, 'VBN': 0.8, 'VBP': 1.2, 'VBZ': 1.2, 'WDT': 0.7, 'WP': 0.7, 'WP$': 0.7, 'WRB': 1.3}

# %%
######################################################
#  The following code is given to you. DO NOT MODIFY.
######################################################
# Run this cell to load the dataset
sentence_df = pd.read_csv(f"{data_dir}/sentence_similarity/dev.csv", sep="\t", header=None, names=["label", "sentence1", "sentence2"])
sentence_df.head()
# Out:
#    label                                          sentence1  \
# 0      1      one woman is measuring another woman's ankle.
# 1      1                         a man is cutting an onion.
# 2      1  a young woman is putting stickers all over her...
# 3      1                    a woman is dancing in the rain.
# 4      1          the man is kissing and hugging the woman.
#
#                                    sentence2
# 0    a woman measures another woman's ankle.
# 1                       a man cuts an onion.
# 2  a woman is applying stickers to her face.
# 3       a woman dances in the rain out side.
# 4      a man is hugging and kissing a woman.

# %%
def get_sentence_embedding(
    sentence: str,
    word_embeddings: GloveEmbeddings,
    use_POS: bool = False,
    pos_weights: Dict[str, float] = None,
):
    """
    Compute the sentence embedding using the word embeddings.

    Inputs:
    - sentence: The input sentence
    - word_embeddings: GloveEmbeddings object
    - use_POS: Whether to use POS tagging
    - pos_weights: Dictionary containing POS weights

    Returns:
    torch.Tensor: The sentence embedding
    """

    sentence_embedding = torch.zeros(word_embeddings['the'].shape)
    tagged_words = nltk.pos_tag(nltk.word_tokenize(sentence.lower()))
    for word, tag in tagged_words:
        if word_embeddings.is_word_in_embeddings(word) and tag in pos_weights:
            weight = pos_weights[tag] if use_POS else 1
            sentence_embedding += weight * word_embeddings[word]
            
    return sentence_embedding


def get_sentence_similarity(
    sentence1: str,
    sentence2: str,
    word_embeddings: GloveEmbeddings,
    use_POS: bool = False,
    pos_weights: Dict[str, float] = None,
):
    """
    Compute the similarity between two sentences.

    Inputs:
    - sentence1: The first input sentence
    - sentence2: The second input sentence
    - word_embeddings: GloveEmbeddings object
    - use_POS: Whether to use POS tagging
    - pos_weights: Dictionary containing POS weights

    Returns:
    float: The similarity between the two sentences
    """

    return cosine_similarity(get_sentence_embedding(sentence1, word_embeddings, use_POS, pos_weights), get_sentence_embedding(sentence2, word_embeddings, use_POS, pos_weights))

# %%
######################################################
#  The following code is given to you. DO NOT MODIFY.
######################################################
exercise4 = Exercise4Runner(
    get_sentence_similarity=get_sentence_similarity,
)

exercise4.evaluate(True) #Set False if you only want to see the final accuracies
# Out:
# Excercise 4: Sentence Similarity
# -----------------
# Answering exercise 4...
# 1. Are the following sentences similar?
#     Sentence 1: one woman is measuring another woman's ankle.
#     Sentence 2: a woman measures another woman's ankle.
#  You answered: Cosine Similarity = 0.97507, Prediction = 1
#
# 2. Are the following sentences similar?
#     Sentence 1: a man is cutting an onion.
#     Sentence 2: a man cuts an onion.
#  You answered: Cosine Similarity = 0.98797, Prediction = 1
#
# 3. Are the following sentences similar?
#     Sentence 1: a young woman is putting stickers all over her face.
#     Sentence 2: a woman is applying stickers to her face.
#  You answered: Cosine Similarity = 0.97890, Prediction = 1
#
# 4. Are the following sentences similar?
#     Sentence 1: a woman is dancing in the rain.
#     Sentence 2: a woman dances in the rain out side.
#  You answered: Cosine Similarity = 0.98421, Prediction = 1
#
# 5. Are the following sentences similar?
#     Sentence 1: the man is kissing and hugging the woman.
#     Sentence 2: a man is hugging and kissing a woman.
#  You answered: Cosine Similarity = 0.98456, Prediction = 1
#
# 6. Are the following sentences similar?
#     Sentence 1: a man is playing the guitar and singing.
#     Sentence 2: a man sings with a guitar.
#  You answered: Cosine Similarity = 0.96995, Prediction = 1
#
# 7. Are the following sentences similar?
#     Sentence 1: a man is doing trick with play cards.
#     Sentence 2: a man is performing a card trick.
#  You answered: Cosine Similarity = 0.96987, Prediction = 1
#
# 8. Are the following sentences similar?
#     Sentence 1: the lady peeled the potatoe.
#     Sentence 2: a woman is peeling a potato.
#  You answered: Cosine Similarity = 0.79479, Prediction = 0
#
# 9. Are the following sentences similar?
#     Sentence 1: a woman and man are dancing in the rain.
#     Sentence 2: a man and woman are dancing in rain.
#  You answered: Cosine Similarity = 0.99760, Prediction = 1
#
# 10. Are the following sentences similar?
#     Sentence 1: two men are fistfighting in a ring.
#     Sentence 2: two men fistfight in a ring.
#  You answered: Cosine Similarity = 0.96398, Prediction = 1
#
# 11. Are the following sentences similar?
#     Sentence 1: a woman is stabbing a potato with a fork.
#     Sentence 2: a woman is puncturing a potato with a fork.
#  You answered: Cosine Similarity = 0.99051, Prediction = 1
#
# 12. Are the following sentences similar?
#     Sentence 1: a boy is playing a key-board.
#     Sentence 2: a little boy is playing a keyboard.
#  You answered: Cosine Similarity = 0.98272, Prediction = 1
#
# 13. Are the following sentences similar?
#     Sentence 1: a woman plays the flute.
#     Sentence 2: a woman is playing the flute.
#  You answered: Cosine Similarity = 0.98751, Prediction = 1
#
# 14. Are the following sentences similar?
#     Sentence 1: a group of people are sweeping water out of a house.
#     Sentence 2: people are sweeping water out of a house.
#  You answered: Cosine Similarity = 0.98943, Prediction = 1
#
# 15. Are the following sentences similar?
#     Sentence 1: a man plays a guitar.
#     Sentence 2: a man is playing a guitar.
#  You answered: Cosine Similarity = 0.98976, Prediction = 1
#
# 16. Are the following sentences similar?
#     Sentence 1: a man is playing a musical keyboard.
#     Sentence 2: a man is playing a keyboard piano.
#  You answered: Cosine Similarity = 0.99014, Prediction = 1
#
# 17. Are the following sentences similar?
#     Sentence 1: a man plays a trumpet.
#     Sentence 2: a man is playing the trumpet.
#  You answered: Cosine Similarity = 0.97485, Prediction = 1
#
# 18. Are the following sentences similar?
#     Sentence 1: the man is eating.
#     Sentence 2: a man is eating food.
#  You answered: Cosine Similarity = 0.97135, Prediction = 1
#
# 19. Are the following sentences similar?
#     Sentence 1: a person is slicing onions.
#     Sentence 2: someone is slicing an onion.
#  You answered: Cosine Similarity = 0.97479, Prediction = 1
#
# 20. Are the following sentences similar?
#     Sentence 1: two dogs and one cat sitting on couch.
#     Sentence 2: two dogs and a cat resting on a couch.
#  You answered: Cosine Similarity = 0.98291, Prediction = 1
#
# 21. Are the following sentences similar?
#     Sentence 1: two green and white trains sitting on the tracks.
#     Sentence 2: two green and white trains are sitting on the train track.
#  You answered: Cosine Similarity = 0.99191, Prediction = 1
#
# 22. Are the following sentences similar?
#     Sentence 1: a man in a top hat rides a white horse.
#     Sentence 2: a man with a top hat riding a white horse.
#  You answered: Cosine Similarity = 0.99566, Prediction = 1
#
# 23. Are the following sentences similar?
#     Sentence 1: blue and red plane in mid-air flight.
#     Sentence 2: a blue and red airplane while in flight.
#  You answered: Cosine Similarity = 0.95913, Prediction = 1
#
# 24. Are the following sentences similar?
#     Sentence 1: a group of horses grazing in a field.
#     Sentence 2: group of horses grazing in grassy field.
#  You answered: Cosine Similarity = 0.95795, Prediction = 1
#
# 25. Are the following sentences similar?
#     Sentence 1: three goats are being rounded up by a dog.
#     Sentence 2: three goats are chased by a dog.
#  You answered: Cosine Similarity = 0.98582, Prediction = 1
#
# 26. Are the following sentences similar?
#     Sentence 1: train in a station.
#     Sentence 2: a train in a station.
#  You answered: Cosine Similarity = 0.99107, Prediction = 1
#
# 27. Are the following sentences similar?
#     Sentence 1: a blue bird standing on a lawn.
#     Sentence 2: blue bird standing on green grass.
#  You answered: Cosine Similarity = 0.95836, Prediction = 1
#
# 28. Are the following sentences similar?
#     Sentence 1: a green car parked at a saloon.
#     Sentence 2: a green car parked outside the saloon.
#  You answered: Cosine Similarity = 0.98753, Prediction = 1
#
# 29. Are the following sentences similar?
#     Sentence 1: group of people sitting around a restaurant dining table.
#     Sentence 2: a group of people sitting at a restaurant table.
#  You answered: Cosine Similarity = 0.98416, Prediction = 1
#
# 30. Are the following sentences similar?
#     Sentence 1: a philips flat-screen tv is shown with its two remote controls.
#     Sentence 2: a phillips flat screen tv with two remote controls.
#  You answered: Cosine Similarity = 0.96246, Prediction = 1
#
# 31. Are the following sentences similar?
#     Sentence 1: the train sits at the train station.
#     Sentence 2: a train parked at a train station.
#  You answered: Cosine Similarity = 0.96875, Prediction = 1
#
# 32. Are the following sentences similar?
#     Sentence 1: three people sit at a picnic table outside of a building painted like a union jack.
#     Sentence 2: three people sit at an outdoor table in front of a building painted like the union jack.
#  You answered: Cosine Similarity = 0.99366, Prediction = 1
#
# 33. Are the following sentences similar?
#     Sentence 1: a bird flies across the water.
#     Sentence 2: a bird flies above the water.
#  You answered: Cosine Similarity = 0.98411, Prediction = 1
#
# 34. Are the following sentences similar?
#     Sentence 1: the dog is running through a field.
#     Sentence 2: a dog runs through a field.
#  You answered: Cosine Similarity = 0.98227, Prediction = 1
#
# 35. Are the following sentences similar?
#     Sentence 1: two boys playing a game of flag football.
#     Sentence 2: two boys are playing flag football.
#  You answered: Cosine Similarity = 0.96986, Prediction = 1
#
# 36. Are the following sentences similar?
#     Sentence 1: one white boy and one black boy stand with arms around each other.
#     Sentence 2: two young boys, one white and one black, are standing with their arms around each other.
#  You answered: Cosine Similarity = 0.98546, Prediction = 1
#
# 37. Are the following sentences similar?
#     Sentence 1: the two dogs are playing in the yard.
#     Sentence 2: two dogs are playing on the grass.
#  You answered: Cosine Similarity = 0.98139, Prediction = 1
#
# 38. Are the following sentences similar?
#     Sentence 1: four children are playing on a trampoline.
#     Sentence 2: four kids are jumping on a trampoline.
#  You answered: Cosine Similarity = 0.97355, Prediction = 1
#
# 39. Are the following sentences similar?
#     Sentence 1: a black dog running into the water.
#     Sentence 2: a black dog running through water.
#  You answered: Cosine Similarity = 0.99385, Prediction = 1
#
# 40. Are the following sentences similar?
#     Sentence 1: a dog jumps into the water.
#     Sentence 2: a dog is jumping into the water.
#  You answered: Cosine Similarity = 0.98871, Prediction = 1
#
# 41. Are the following sentences similar?
#     Sentence 1: a man and a dog on rocks on a beach.
#     Sentence 2: a man and dog on a rocky seashore.
#  You answered: Cosine Similarity = 0.98090, Prediction = 1
#
# 42. Are the following sentences similar?
#     Sentence 1: two dogs are running in the field.
#     Sentence 2: two dogs running in a field.
#  You answered: Cosine Similarity = 0.98326, Prediction = 1
#
# 43. Are the following sentences similar?
#     Sentence 1: two brown dogs runs through the water.
#     Sentence 2: two brown dogs running through water.
#  You answered: Cosine Similarity = 0.98740, Prediction = 1
#
# 44. Are the following sentences similar?
#     Sentence 1: a man climbing a rock-face.
#     Sentence 2: a man is climbing a rock wall.
#  You answered: Cosine Similarity = 0.96694, Prediction = 1
#
# 45. Are the following sentences similar?
#     Sentence 1: the surfer does a flip off of a wave.
#     Sentence 2: a surfer does a flip on a wave.
#  You answered: Cosine Similarity = 0.98924, Prediction = 1
#
# 46. Are the following sentences similar?
#     Sentence 1: a blonde haired toddler swinging on a tire swing.
#     Sentence 2: a blonde haired child is swinging on a tire swing.
#  You answered: Cosine Similarity = 0.97920, Prediction = 1
#
# 47. Are the following sentences similar?
#     Sentence 1: one boy is pushing another boy on a swing.
#     Sentence 2: a boy is pushing another boy on the swings.
#  You answered: Cosine Similarity = 0.99305, Prediction = 1
#
# 48. Are the following sentences similar?
#     Sentence 1: two black dogs are playing on the grass.
#     Sentence 2: two black dogs are playing in a grassy plain.
#  You answered: Cosine Similarity = 0.97561, Prediction = 1
#
# 49. Are the following sentences similar?
#     Sentence 1: a man in a black suit is surfing along a crashing wave.
#     Sentence 2: a surfer wearing a black wet suit is riding a a white wave in the ocean.
#  You answered: Cosine Similarity = 0.98217, Prediction = 1
#
# 50. Are the following sentences similar?
#     Sentence 1: a man running on a track.
#     Sentence 2: a man running track
#  You answered: Cosine Similarity = 0.98958, Prediction = 1
#
# 51. Are the following sentences similar?
#     Sentence 1: a man steers a blue boat past brightly colored houses.
#     Sentence 2: a man driving a blue boat passes by some colorful houses.
#  You answered: Cosine Similarity = 0.96526, Prediction = 1
#
# 52. Are the following sentences similar?
#     Sentence 1: a deer jumps a fence.
#     Sentence 2: a deer is jumping over a fence.
#  You answered: Cosine Similarity = 0.96554, Prediction = 1
#
# 53. Are the following sentences similar?
#     Sentence 1: a young person  deep in thought.
#     Sentence 2: a young man deep in thought.
#  You answered: Cosine Similarity = 0.99137, Prediction = 1
#
# 54. Are the following sentences similar?
#     Sentence 1: some guy sitting on a couch watching television.
#     Sentence 2: a guy is sitting on the couch watching tv
#  You answered: Cosine Similarity = 0.98637, Prediction = 1
#
# 55. Are the following sentences similar?
#     Sentence 1: there is a cook preparing food.
#     Sentence 2: a cook is making food.
#  You answered: Cosine Similarity = 0.98670, Prediction = 1
#
# 56. Are the following sentences similar?
#     Sentence 1: people gathered in a room.
#     Sentence 2: people gathered together in a room.
#  You answered: Cosine Similarity = 0.99228, Prediction = 1
#
# 57. Are the following sentences similar?
#     Sentence 1: people getting their dirty clothes cleaned
#     Sentence 2: people are getting their clothes cleaned.
#  You answered: Cosine Similarity = 0.97821, Prediction = 1
#
# 58. Are the following sentences similar?
#     Sentence 1: a man is laughing with a woman
#     Sentence 2: a man and a woman laughing.
#  You answered: Cosine Similarity = 0.99510, Prediction = 1
#
# 59. Are the following sentences similar?
#     Sentence 1: the people are running a marathon
#     Sentence 2: people are running a marathon
#  You answered: Cosine Similarity = 0.99487, Prediction = 1
#
# 60. Are the following sentences similar?
#     Sentence 1: a brown dog is jumping.
#     Sentence 2: a brown dog is jumping
#  You answered: Cosine Similarity = 1.00000, Prediction = 1
#
# 61. Are the following sentences similar?
#     Sentence 1: you do not need to worry.
#     Sentence 2: you don't have to worry.
#  You answered: Cosine Similarity = 0.99234, Prediction = 1
#
# 62. Are the following sentences similar?
#     Sentence 1: you can do it, too.
#     Sentence 2: yes, you can do it.
#  You answered: Cosine Similarity = 0.99258, Prediction = 1
#
# 63. Are the following sentences similar?
#     Sentence 1: the answer to both questions is: yes.
#     Sentence 2: the answer to both of your questions is yes.
#  You answered: Cosine Similarity = 0.99243, Prediction = 1
#
# 64. Are the following sentences similar?
#     Sentence 1: you guys are making this all waaaaay too complicated.
#     Sentence 2: you are making this too complicated.
#  You answered: Cosine Similarity = 0.99215, Prediction = 1
#
# 65. Are the following sentences similar?
#     Sentence 1: it's not a good idea.
#     Sentence 2: it is not a good idea.
#  You answered: Cosine Similarity = 0.99292, Prediction = 1
#
# 66. Are the following sentences similar?
#     Sentence 1: take a look at these:
#     Sentence 2: take a look at this:
#  You answered: Cosine Similarity = 0.98899, Prediction = 1
#
# 67. Are the following sentences similar?
#     Sentence 1: this is not a good idea.
#     Sentence 2: but it is not a good idea.
#  You answered: Cosine Similarity = 0.99661, Prediction = 1
#
# 68. Are the following sentences similar?
#     Sentence 1: i was in a similar situation.
#     Sentence 2: i had a similar situation.
#  You answered: Cosine Similarity = 0.98785, Prediction = 1
#
# 69. Are the following sentences similar?
#     Sentence 1: i've had this same problem.
#     Sentence 2: i had this same problem.
#  You answered: Cosine Similarity = 0.99532, Prediction = 1
#
# 70. Are the following sentences similar?
#     Sentence 1: you answered your own question.
#     Sentence 2: you have answered your own question.
#  You answered: Cosine Similarity = 0.99020, Prediction = 1
#
# 71. Are the following sentences similar?
#     Sentence 1: i don't see why there should be any problem with this whatsoever.
#     Sentence 2: i don't see why that should be a problem.
#  You answered: Cosine Similarity = 0.99304, Prediction = 1
#
# 72. Are the following sentences similar?
#     Sentence 1: it makes absolutely no difference.
#     Sentence 2: no, it makes no difference.
#  You answered: Cosine Similarity = 0.98853, Prediction = 1
#
# 73. Are the following sentences similar?
#     Sentence 1: i think it's fine to ask this question.
#     Sentence 2: i think it is okay to ask the question.
#  You answered: Cosine Similarity = 0.98886, Prediction = 1
#
# 74. Are the following sentences similar?
#     Sentence 1: there's not a lot you can do about that.
#     Sentence 2: i'm afraid there's not really a lot you can do.
#  You answered: Cosine Similarity = 0.97886, Prediction = 1
#
# 75. Are the following sentences similar?
#     Sentence 1: you answered your own question.
#     Sentence 2: you've answered your own question already.
#  You answered: Cosine Similarity = 0.98452, Prediction = 1
#
# 76. Are the following sentences similar?
#     Sentence 1: can you do this?
#     Sentence 2: can you do it?
#  You answered: Cosine Similarity = 0.99696, Prediction = 1
#
# 77. Are the following sentences similar?
#     Sentence 1: how do you do that?
#     Sentence 2: how to do that?
#  You answered: Cosine Similarity = 0.97609, Prediction = 1
#
# 78. Are the following sentences similar?
#     Sentence 1: it's also a matter of taste.
#     Sentence 2: it's definitely just a matter of preference.
#  You answered: Cosine Similarity = 0.98046, Prediction = 1
#
# 79. Are the following sentences similar?
#     Sentence 1: i don't see why there should be any problem with this whatsoever.
#     Sentence 2: i don't see why this could be a problem.
#  You answered: Cosine Similarity = 0.99156, Prediction = 1
#
# 80. Are the following sentences similar?
#     Sentence 1: there's not a lot you can do about that.
#     Sentence 2: i really do not think there is much you can do about that.
#  You answered: Cosine Similarity = 0.98835, Prediction = 1
#
# 81. Are the following sentences similar?
#     Sentence 1: you got it right.
#     Sentence 2: yes you got it.
#  You answered: Cosine Similarity = 0.98264, Prediction = 1
#
# 82. Are the following sentences similar?
#     Sentence 1: there are two things to consider:
#     Sentence 2: a couple things to consider:
#  You answered: Cosine Similarity = 0.95558, Prediction = 1
#
# 83. Are the following sentences similar?
#     Sentence 1: can you do this?
#     Sentence 2: so, can you do this?
#  You answered: Cosine Similarity = 0.99757, Prediction = 1
#
# 84. Are the following sentences similar?
#     Sentence 1: there are a few things you can do:
#     Sentence 2: there are a couple things you can try.
#  You answered: Cosine Similarity = 0.99334, Prediction = 1
#
# 85. Are the following sentences similar?
#     Sentence 1: you got it right.
#     Sentence 2: you've got it right.
#  You answered: Cosine Similarity = 0.99511, Prediction = 1
#
# 86. Are the following sentences similar?
#     Sentence 1: you answered your own question.
#     Sentence 2: you pretty much answered your own question.
#  You answered: Cosine Similarity = 0.98549, Prediction = 1
#
# 87. Are the following sentences similar?
#     Sentence 1: you are on the right path.
#     Sentence 2: you're on the right path.
#  You answered: Cosine Similarity = 0.98830, Prediction = 1
#
# 88. Are the following sentences similar?
#     Sentence 1: what are your goals?
#     Sentence 2: what are you goals?
#  You answered: Cosine Similarity = 0.98947, Prediction = 1
#
# 89. Are the following sentences similar?
#     Sentence 1: a few more point to think about:
#     Sentence 2: a few things to think about:
#  You answered: Cosine Similarity = 0.98708, Prediction = 1
#
# 90. Are the following sentences similar?
#     Sentence 1: i'm afraid we are out of luck in this one.
#     Sentence 2: i think this is one of those things where you are just out of luck.
#  You answered: Cosine Similarity = 0.99293, Prediction = 1
#
# 91. Are the following sentences similar?
#     Sentence 1: it's also a matter of taste.
#     Sentence 2: it's mostly a matter of taste.
#  You answered: Cosine Similarity = 0.99252, Prediction = 1
#
# 92. Are the following sentences similar?
#     Sentence 1: i had the same problem as you.
#     Sentence 2: i have just had the same problem.
#  You answered: Cosine Similarity = 0.99030, Prediction = 1
#
# 93. Are the following sentences similar?
#     Sentence 1: i'm thinking it's a bad idea.
#     Sentence 2: i think it's a bad idea.
#  You answered: Cosine Similarity = 0.99511, Prediction = 1
#
# 94. Are the following sentences similar?
#     Sentence 1: it's not a good idea.
#     Sentence 2: not a good idea.
#  You answered: Cosine Similarity = 0.99060, Prediction = 1
#
# 95. Are the following sentences similar?
#     Sentence 1: i had the same problem as you.
#     Sentence 2: i have exactly the same problem.
#  You answered: Cosine Similarity = 0.98993, Prediction = 1
#
# 96. Are the following sentences similar?
#     Sentence 1: there are two things to consider:
#     Sentence 2: i think there are two important things to consider:
#  You answered: Cosine Similarity = 0.98564, Prediction = 1
#
# 97. Are the following sentences similar?
#     Sentence 1: it's pretty much up to you.
#     Sentence 2: it is up to you.
#  You answered: Cosine Similarity = 0.98497, Prediction = 1
#
# 98. Are the following sentences similar?
#     Sentence 1: there are three options:
#     Sentence 2: there are only three options:
#  You answered: Cosine Similarity = 0.99641, Prediction = 1
#
# 99. Are the following sentences similar?
#     Sentence 1: so think it in this way.
#     Sentence 2: think of it this way.
#  You answered: Cosine Similarity = 0.99465, Prediction = 1
#
# 100. Are the following sentences similar?
#     Sentence 1: maybe this could work for you.
#     Sentence 2: maybe this can work for you.
#  You answered: Cosine Similarity = 0.99558, Prediction = 1
#
# 101. Are the following sentences similar?
#     Sentence 1: the woman is styling her hair.
#     Sentence 2: the woman is slicing herbs.
#  You answered: Cosine Similarity = 0.88345, Prediction = 0
#
# 102. Are the following sentences similar?
#     Sentence 1: a man is kicking pots of water.
#     Sentence 2: a man is picking flowers.
#  You answered: Cosine Similarity = 0.92728, Prediction = 0
#
# 103. Are the following sentences similar?
#     Sentence 1: a man is playing a guitar.
#     Sentence 2: a man is driving a car.
#  You answered: Cosine Similarity = 0.92230, Prediction = 0
#
# 104. Are the following sentences similar?
#     Sentence 1: a woman is dancing.
#     Sentence 2: a woman is playing violin.
#  You answered: Cosine Similarity = 0.93866, Prediction = 0
#
# 105. Are the following sentences similar?
#     Sentence 1: a woman is water skiing.
#     Sentence 2: a woman is slicing fish.
#  You answered: Cosine Similarity = 0.89910, Prediction = 0
#
# 106. Are the following sentences similar?
#     Sentence 1: a woman is picking a can.
#     Sentence 2: a man is playing a guitar.
#  You answered: Cosine Similarity = 0.93628, Prediction = 0
#
# 107. Are the following sentences similar?
#     Sentence 1: a woman is cutting an onion.
#     Sentence 2: a woman is cleaning a garden.
#  You answered: Cosine Similarity = 0.95196, Prediction = 1
#
# 108. Are the following sentences similar?
#     Sentence 1: a train is moving.
#     Sentence 2: a man is doing yoga.
#  You answered: Cosine Similarity = 0.86864, Prediction = 0
#
# 109. Are the following sentences similar?
#     Sentence 1: a man is holding a leaf.
#     Sentence 2: a monkey is fighting a man.
#  You answered: Cosine Similarity = 0.95998, Prediction = 1
#
# 110. Are the following sentences similar?
#     Sentence 1: a woman is peeling shrimp.
#     Sentence 2: a man is squeezing water.
#  You answered: Cosine Similarity = 0.91663, Prediction = 0
#
# 111. Are the following sentences similar?
#     Sentence 1: a man is playing a guitar.
#     Sentence 2: a woman is riding a horse.
#  You answered: Cosine Similarity = 0.90442, Prediction = 0
#
# 112. Are the following sentences similar?
#     Sentence 1: a woman opens a window.
#     Sentence 2: a man is crawling.
#  You answered: Cosine Similarity = 0.90920, Prediction = 0
#
# 113. Are the following sentences similar?
#     Sentence 1: a woman is filing her nails.
#     Sentence 2: a man is peeling a carrot.
#  You answered: Cosine Similarity = 0.89973, Prediction = 0
#
# 114. Are the following sentences similar?
#     Sentence 1: a woman is swimming underwater.
#     Sentence 2: a man is slicing some carrots.
#  You answered: Cosine Similarity = 0.78899, Prediction = 0
#
# 115. Are the following sentences similar?
#     Sentence 1: a man is opening a box and taking out paper.
#     Sentence 2: a woman is peeling a potato.
#  You answered: Cosine Similarity = 0.90040, Prediction = 0
#
# 116. Are the following sentences similar?
#     Sentence 1: a woman is cracking eggs.
#     Sentence 2: a man is talking to a woman.
#  You answered: Cosine Similarity = 0.93344, Prediction = 0
#
# 117. Are the following sentences similar?
#     Sentence 1: a cat is walking around a house.
#     Sentence 2: a woman is peeling potato.
#  You answered: Cosine Similarity = 0.89490, Prediction = 0
#
# 118. Are the following sentences similar?
#     Sentence 1: a woman is talking to her pet bunny as she fondles it.
#     Sentence 2: a woman walks her dog onto astro turf.
#  You answered: Cosine Similarity = 0.90784, Prediction = 0
#
# 119. Are the following sentences similar?
#     Sentence 1: a man is playing guitar.
#     Sentence 2: a boy is talking to a giant dog.
#  You answered: Cosine Similarity = 0.90287, Prediction = 0
#
# 120. Are the following sentences similar?
#     Sentence 1: a cat is playing on the floor.
#     Sentence 2: a man is slicing garlic.
#  You answered: Cosine Similarity = 0.85582, Prediction = 0
#
# 121. Are the following sentences similar?
#     Sentence 1: a boy is playing violin on stage.
#     Sentence 2: a person is mixing a pot.
#  You answered: Cosine Similarity = 0.87497, Prediction = 0
#
# 122. Are the following sentences similar?
#     Sentence 1: a woman is slicing ginger.
#     Sentence 2: a person is holding two baby lorises.
#  You answered: Cosine Similarity = 0.86967, Prediction = 0
#
# 123. Are the following sentences similar?
#     Sentence 1: a woman is spreading mustard on a bread roll.
#     Sentence 2: a kitten is playing with a woman's finger.
#  You answered: Cosine Similarity = 0.92263, Prediction = 0
#
# 124. Are the following sentences similar?
#     Sentence 1: someone touched the kitten chewing on a string.
#     Sentence 2: someone is cutting paper.
#  You answered: Cosine Similarity = 0.87533, Prediction = 0
#
# 125. Are the following sentences similar?
#     Sentence 1: meat is being put into a skillet.
#     Sentence 2: a woman is putting a baby into a trash can.
#  You answered: Cosine Similarity = 0.92259, Prediction = 0
#
# 126. Are the following sentences similar?
#     Sentence 1: a baby elephant is eating a small tree.
#     Sentence 2: a little girl peddling a scooter.
#  You answered: Cosine Similarity = 0.86349, Prediction = 0
#
# 127. Are the following sentences similar?
#     Sentence 1: someone is drawing.
#     Sentence 2: someone is dancing.
#  You answered: Cosine Similarity = 0.92887, Prediction = 0
#
# 128. Are the following sentences similar?
#     Sentence 1: a person is playing a piano.
#     Sentence 2: a person is slicing a potato.
#  You answered: Cosine Similarity = 0.89816, Prediction = 0
#
# 129. Are the following sentences similar?
#     Sentence 1: a man is dancing.
#     Sentence 2: a woman is exercising.
#  You answered: Cosine Similarity = 0.93509, Prediction = 0
#
# 130. Are the following sentences similar?
#     Sentence 1: a woman is exercising.
#     Sentence 2: a man is dancing.
#  You answered: Cosine Similarity = 0.93509, Prediction = 0
#
# 131. Are the following sentences similar?
#     Sentence 1: a man is doing exercise.
#     Sentence 2: a man is firing a rifle.
#  You answered: Cosine Similarity = 0.91062, Prediction = 0
#
# 132. Are the following sentences similar?
#     Sentence 1: a man is playing a piano.
#     Sentence 2: a guy is peeling a potato.
#  You answered: Cosine Similarity = 0.88039, Prediction = 0
#
# 133. Are the following sentences similar?
#     Sentence 1: a man is bowling.
#     Sentence 2: a kitten is walking.
#  You answered: Cosine Similarity = 0.91415, Prediction = 0
#
# 134. Are the following sentences similar?
#     Sentence 1: a woman is dancing near a fire.
#     Sentence 2: a woman is cutting a tomatoe.
#  You answered: Cosine Similarity = 0.95166, Prediction = 1
#
# 135. Are the following sentences similar?
#     Sentence 1: a person is riding a motorcyle.
#     Sentence 2: a person is chopping an onion.
#  You answered: Cosine Similarity = 0.85473, Prediction = 0
#
# 136. Are the following sentences similar?
#     Sentence 1: a man is talking on the phone.
#     Sentence 2: a man is moon-walking across a store.
#  You answered: Cosine Similarity = 0.96556, Prediction = 1
#
# 137. Are the following sentences similar?
#     Sentence 1: a woman is braiding her hair.
#     Sentence 2: a man is riding a motorcycle.
#  You answered: Cosine Similarity = 0.85563, Prediction = 0
#
# 138. Are the following sentences similar?
#     Sentence 1: the woman is slicing tofu.
#     Sentence 2: the woman is putting on lipstick.
#  You answered: Cosine Similarity = 0.90452, Prediction = 0
#
# 139. Are the following sentences similar?
#     Sentence 1: a woman is folding paper.
#     Sentence 2: a woman is applying eye shadow.
#  You answered: Cosine Similarity = 0.93569, Prediction = 0
#
# 140. Are the following sentences similar?
#     Sentence 1: someone is folding a piece of paper.
#     Sentence 2: a person is slicing a small pieces of ginger.
#  You answered: Cosine Similarity = 0.95104, Prediction = 1
#
# 141. Are the following sentences similar?
#     Sentence 1: a man is lifting weights.
#     Sentence 2: a man is chopping egg plant.
#  You answered: Cosine Similarity = 0.86423, Prediction = 0
#
# 142. Are the following sentences similar?
#     Sentence 1: a man is playing a cello.
#     Sentence 2: a man is rapidly lifting small weights.
#  You answered: Cosine Similarity = 0.86980, Prediction = 0
#
# 143. Are the following sentences similar?
#     Sentence 1: the man is talking.
#     Sentence 2: a man is walking down stairs.
#  You answered: Cosine Similarity = 0.92102, Prediction = 0
#
# 144. Are the following sentences similar?
#     Sentence 1: a man is playing the drums.
#     Sentence 2: a woman is slicing some leaves.
#  You answered: Cosine Similarity = 0.88757, Prediction = 0
#
# 145. Are the following sentences similar?
#     Sentence 1: a man is hitting a boy with flower vase.
#     Sentence 2: a man is cutting a mat.
#  You answered: Cosine Similarity = 0.94423, Prediction = 0
#
# 146. Are the following sentences similar?
#     Sentence 1: the man is mixing whipping cream.
#     Sentence 2: the man is holding a skunk.
#  You answered: Cosine Similarity = 0.88196, Prediction = 0
#
# 147. Are the following sentences similar?
#     Sentence 1: a man is singing while playing the guitar.
#     Sentence 2: a man is stuffing himself full with food.
#  You answered: Cosine Similarity = 0.89469, Prediction = 0
#
# 148. Are the following sentences similar?
#     Sentence 1: a boat sails along the water.
#     Sentence 2: the man is playing the guitar.
#  You answered: Cosine Similarity = 0.80621, Prediction = 0
#
# 149. Are the following sentences similar?
#     Sentence 1: an okapi is eating from a tree.
#     Sentence 2: a moose drinks from a sprinkler.
#  You answered: Cosine Similarity = 0.91627, Prediction = 0
#
# 150. Are the following sentences similar?
#     Sentence 1: a woman is pouring egg into a frying pan.
#     Sentence 2: a man is petting two dogs.
#  You answered: Cosine Similarity = 0.85424, Prediction = 0
#
# 151. Are the following sentences similar?
#     Sentence 1: a woman is frying ground meat.
#     Sentence 2: a man is cutting a trunk with an axe.
#  You answered: Cosine Similarity = 0.89437, Prediction = 0
#
# 152. Are the following sentences similar?
#     Sentence 1: a person is boiling noodles.
#     Sentence 2: a cat is licking a bottle.
#  You answered: Cosine Similarity = 0.86789, Prediction = 0
#
# 153. Are the following sentences similar?
#     Sentence 1: a man reels in a fish.
#     Sentence 2: a woman is pouring oil in a bowl.
#  You answered: Cosine Similarity = 0.94626, Prediction = 0
#
# 154. Are the following sentences similar?
#     Sentence 1: a woman is cutting an onion.
#     Sentence 2: a horse is standing.
#  You answered: Cosine Similarity = 0.91492, Prediction = 0
#
# 155. Are the following sentences similar?
#     Sentence 1: a person is adding food in a pan.
#     Sentence 2: a man is dancing in the street.
#  You answered: Cosine Similarity = 0.91867, Prediction = 0
#
# 156. Are the following sentences similar?
#     Sentence 1: a man is smoking.
#     Sentence 2: a baby is sucking on a pacifier.
#  You answered: Cosine Similarity = 0.91626, Prediction = 0
#
# 157. Are the following sentences similar?
#     Sentence 1: a person is putting shredded cheese in a pot.
#     Sentence 2: a hamster is eating some seeds.
#  You answered: Cosine Similarity = 0.89708, Prediction = 0
#
# 158. Are the following sentences similar?
#     Sentence 1: a man is erasing a chalk board.
#     Sentence 2: a woman is dancing, and singing.
#  You answered: Cosine Similarity = 0.85789, Prediction = 0
#
# 159. Are the following sentences similar?
#     Sentence 1: a chimp is kicking a target.
#     Sentence 2: a woman is putting oil into a skillet.
#  You answered: Cosine Similarity = 0.88920, Prediction = 0
#
# 160. Are the following sentences similar?
#     Sentence 1: a man is doing exercise.
#     Sentence 2: a baby is laughing.
#  You answered: Cosine Similarity = 0.91474, Prediction = 0
#
# 161. Are the following sentences similar?
#     Sentence 1: the girl is carrying a baby.
#     Sentence 2: a man is eating a food.
#  You answered: Cosine Similarity = 0.93524, Prediction = 0
#
# 162. Are the following sentences similar?
#     Sentence 1: a man spins on a surf board.
#     Sentence 2: a man is putting barbecue sauce on chicken.
#  You answered: Cosine Similarity = 0.86269, Prediction = 0
#
# 163. Are the following sentences similar?
#     Sentence 1: two men are dancing together.
#     Sentence 2: a woman opens a closet.
#  You answered: Cosine Similarity = 0.69461, Prediction = 0
#
# 164. Are the following sentences similar?
#     Sentence 1: a man is reading an email.
#     Sentence 2: a person opening a banana.
#  You answered: Cosine Similarity = 0.89428, Prediction = 0
#
# 165. Are the following sentences similar?
#     Sentence 1: the flock of sheep are spread out in the field.
#     Sentence 2: a white cat stands on the floor.
#  You answered: Cosine Similarity = 0.87967, Prediction = 0
#
# 166. Are the following sentences similar?
#     Sentence 1: a man sitting in a back yard playing the guitar.
#     Sentence 2: a man riding on the back of an orange suv.
#  You answered: Cosine Similarity = 0.94622, Prediction = 0
#
# 167. Are the following sentences similar?
#     Sentence 1: a woman riding a brown horse.
#     Sentence 2: a woman taking her own photo from above.
#  You answered: Cosine Similarity = 0.89594, Prediction = 0
#
# 168. Are the following sentences similar?
#     Sentence 1: two men standing in grass staring at a car.
#     Sentence 2: a woman in a pink top posing with beer.
#  You answered: Cosine Similarity = 0.91074, Prediction = 0
#
# 169. Are the following sentences similar?
#     Sentence 1: the train heads down the tracks and along the hedge.
#     Sentence 2: a dog on the floor of a patio looks at a cat on the fence.
#  You answered: Cosine Similarity = 0.91461, Prediction = 0
#
# 170. Are the following sentences similar?
#     Sentence 1: a little girl is laughing at the camera.
#     Sentence 2: a white cow with big ears looking into the camera.
#  You answered: Cosine Similarity = 0.94277, Prediction = 0
#
# 171. Are the following sentences similar?
#     Sentence 1: a man dressed in a pale scarf with a stick.
#     Sentence 2: a runner is resting in the shade with a bottle of soda.
#  You answered: Cosine Similarity = 0.92717, Prediction = 0
#
# 172. Are the following sentences similar?
#     Sentence 1: a very retro living room with a television in it.
#     Sentence 2: a grey cat lying on a wooden table.
#  You answered: Cosine Similarity = 0.88104, Prediction = 0
#
# 173. Are the following sentences similar?
#     Sentence 1: a man sitting cross legged on the grass, with a tree in the background.
#     Sentence 2: ocean liner close to coast with houses in the background.
#  You answered: Cosine Similarity = 0.90969, Prediction = 0
#
# 174. Are the following sentences similar?
#     Sentence 1: two men standing in grass staring at a car.
#     Sentence 2: two women sitting in chairs in a shop.
#  You answered: Cosine Similarity = 0.95496, Prediction = 1
#
# 175. Are the following sentences similar?
#     Sentence 1: a woman stands in front of a building in the snow.
#     Sentence 2: two women and a baby pose in front of a dining room.
#  You answered: Cosine Similarity = 0.96196, Prediction = 1
#
# 176. Are the following sentences similar?
#     Sentence 1: a yellow school bus parked in a field.
#     Sentence 2: a brown horse in a green field.
#  You answered: Cosine Similarity = 0.92516, Prediction = 0
#
# 177. Are the following sentences similar?
#     Sentence 1: the cat is sitting on a bag of cat food.
#     Sentence 2: two eagles sitting on a long branch.
#  You answered: Cosine Similarity = 0.89210, Prediction = 0
#
# 178. Are the following sentences similar?
#     Sentence 1: a women painting a chair with a dining room in the background.
#     Sentence 2: a man and boy walking along a beach with the sea in the background.
#  You answered: Cosine Similarity = 0.94924, Prediction = 0
#
# 179. Are the following sentences similar?
#     Sentence 1: a cruise ship is in front of a docking area.
#     Sentence 2: calico cat sitting on step in front of a door.
#  You answered: Cosine Similarity = 0.92949, Prediction = 0
#
# 180. Are the following sentences similar?
#     Sentence 1: a black and white cow standing in hay looks back at the camera.
#     Sentence 2: there is a black and white sheep standing on the grass.
#  You answered: Cosine Similarity = 0.97469, Prediction = 1
#
# 181. Are the following sentences similar?
#     Sentence 1: two animals sitting on a rock.
#     Sentence 2: the brown train is sitting on the railroad tracks.
#  You answered: Cosine Similarity = 0.92309, Prediction = 0
#
# 182. Are the following sentences similar?
#     Sentence 1: a small camouflaged airplane parked in the grass.
#     Sentence 2: a small dog wearing a pink shirt tied to a railing.
#  You answered: Cosine Similarity = 0.89636, Prediction = 0
#
# 183. Are the following sentences similar?
#     Sentence 1: a man and a woman watch two dogs.
#     Sentence 2: a man in a maroon bathing suit swings on a rope on a lake.
#  You answered: Cosine Similarity = 0.93282, Prediction = 0
#
# 184. Are the following sentences similar?
#     Sentence 1: a man and a woman are standing in front of a building
#     Sentence 2: two girls are sitting on an atv on the sand in front of a bridge.
#  You answered: Cosine Similarity = 0.96600, Prediction = 1
#
# 185. Are the following sentences similar?
#     Sentence 1: a woman in a black and orange jacket throws a stick for a brown and black dog to fetch.
#     Sentence 2: the man in a blue jacket is standing in a crowd.
#  You answered: Cosine Similarity = 0.96338, Prediction = 1
#
# 186. Are the following sentences similar?
#     Sentence 1: two racing dogs run in the mud.
#     Sentence 2: the man is going into the water.
#  You answered: Cosine Similarity = 0.92334, Prediction = 0
#
# 187. Are the following sentences similar?
#     Sentence 1: a man in a suit dances with a young girl in front of an audience.
#     Sentence 2: a women dangles from a blue fabric connected to a tree.
#  You answered: Cosine Similarity = 0.94744, Prediction = 0
#
# 188. Are the following sentences similar?
#     Sentence 1: a man and woman walking past a record shop
#     Sentence 2: a man and woman kissing in front of a crowd of people.
#  You answered: Cosine Similarity = 0.95890, Prediction = 1
#
# 189. Are the following sentences similar?
#     Sentence 1: a boy in red jumping into a sandbox.
#     Sentence 2: a dog swimming in a pond
#  You answered: Cosine Similarity = 0.93802, Prediction = 0
#
# 190. Are the following sentences similar?
#     Sentence 1: two people are in bed.
#     Sentence 2: two boxers are in the ring.
#  You answered: Cosine Similarity = 0.92764, Prediction = 0
#
# 191. Are the following sentences similar?
#     Sentence 1: a red haired women in black is posing for a man while resting on a tree.
#     Sentence 2: a man in a black shirt is holding a child wearing sunglasses.
#  You answered: Cosine Similarity = 0.97001, Prediction = 1
#
# 192. Are the following sentences similar?
#     Sentence 1: a dog standing in the water.
#     Sentence 2: a girl playing on a parachute.
#  You answered: Cosine Similarity = 0.90780, Prediction = 0
#
# 193. Are the following sentences similar?
#     Sentence 1: a brown and white dog is running across a brown field.
#     Sentence 2: a person hanging from a rocky cliff.
#  You answered: Cosine Similarity = 0.93124, Prediction = 0
#
# 194. Are the following sentences similar?
#     Sentence 1: a man in a wet suit is throwing a baby wearing a wet suit up into the air.
#     Sentence 2: a man in a white print shirt and a woman in a black dress dancing.
#  You answered: Cosine Similarity = 0.96438, Prediction = 1
#
# 195. Are the following sentences similar?
#     Sentence 1: many football players sitting on the ground.
#     Sentence 2: a dog rolls on the ground.
#  You answered: Cosine Similarity = 0.88507, Prediction = 0
#
# 196. Are the following sentences similar?
#     Sentence 1: a little boy and a little girl playing together outside.
#     Sentence 2: a woman wearing a white shirt stands on the street.
#  You answered: Cosine Similarity = 0.91374, Prediction = 0
#
# 197. Are the following sentences similar?
#     Sentence 1: the woman is holding the harness that the brown and white dog is wearing.
#     Sentence 2: a man and woman are looking at artwork that is on easels and clipped to a fencing wall.
#  You answered: Cosine Similarity = 0.95671, Prediction = 1
#
# 198. Are the following sentences similar?
#     Sentence 1: a young pitcher is throwing the baseball.
#     Sentence 2: a brown dog is walking on the grass beside a fence.
#  You answered: Cosine Similarity = 0.87903, Prediction = 0
#
# 199. Are the following sentences similar?
#     Sentence 1: a woman in a blue bathing suit is jumping off a dock into a lake.
#     Sentence 2: a boy in a blue shirt and blue jeans runs across a playground
#  You answered: Cosine Similarity = 0.94711, Prediction = 0
#
# 200. Are the following sentences similar?
#     Sentence 1: a little girl in an orange striped outfit is airborne whilst bouncing on a bed.
#     Sentence 2: a dog in a red shirt is chasing a squirrel through the glass.
#  You answered: Cosine Similarity = 0.97977, Prediction = 1
#
# Answering exercise 4...
# 1. Are the following sentences similar?
#     Sentence 1: one woman is measuring another woman's ankle.
#     Sentence 2: a woman measures another woman's ankle.
#  You answered: Cosine Similarity = 0.95473, Prediction = 1
#
# 2. Are the following sentences similar?
#     Sentence 1: a man is cutting an onion.
#     Sentence 2: a man cuts an onion.
#  You answered: Cosine Similarity = 0.97441, Prediction = 1
#
# 3. Are the following sentences similar?
#     Sentence 1: a young woman is putting stickers all over her face.
#     Sentence 2: a woman is applying stickers to her face.
#  You answered: Cosine Similarity = 0.97663, Prediction = 1
#
# 4. Are the following sentences similar?
#     Sentence 1: a woman is dancing in the rain.
#     Sentence 2: a woman dances in the rain out side.
#  You answered: Cosine Similarity = 0.97875, Prediction = 1
#
# 5. Are the following sentences similar?
#     Sentence 1: the man is kissing and hugging the woman.
#     Sentence 2: a man is hugging and kissing a woman.
#  You answered: Cosine Similarity = 0.98981, Prediction = 1
#
# 6. Are the following sentences similar?
#     Sentence 1: a man is playing the guitar and singing.
#     Sentence 2: a man sings with a guitar.
#  You answered: Cosine Similarity = 0.95624, Prediction = 1
#
# 7. Are the following sentences similar?
#     Sentence 1: a man is doing trick with play cards.
#     Sentence 2: a man is performing a card trick.
#  You answered: Cosine Similarity = 0.96835, Prediction = 1
#
# 8. Are the following sentences similar?
#     Sentence 1: the lady peeled the potatoe.
#     Sentence 2: a woman is peeling a potato.
#  You answered: Cosine Similarity = 0.76037, Prediction = 0
#
# 9. Are the following sentences similar?
#     Sentence 1: a woman and man are dancing in the rain.
#     Sentence 2: a man and woman are dancing in rain.
#  You answered: Cosine Similarity = 0.99815, Prediction = 1
#
# 10. Are the following sentences similar?
#     Sentence 1: two men are fistfighting in a ring.
#     Sentence 2: two men fistfight in a ring.
#  You answered: Cosine Similarity = 0.92607, Prediction = 0
#
# 11. Are the following sentences similar?
#     Sentence 1: a woman is stabbing a potato with a fork.
#     Sentence 2: a woman is puncturing a potato with a fork.
#  You answered: Cosine Similarity = 0.98223, Prediction = 1
#
# 12. Are the following sentences similar?
#     Sentence 1: a boy is playing a key-board.
#     Sentence 2: a little boy is playing a keyboard.
#  You answered: Cosine Similarity = 0.98609, Prediction = 1
#
# 13. Are the following sentences similar?
#     Sentence 1: a woman plays the flute.
#     Sentence 2: a woman is playing the flute.
#  You answered: Cosine Similarity = 0.97556, Prediction = 1
#
# 14. Are the following sentences similar?
#     Sentence 1: a group of people are sweeping water out of a house.
#     Sentence 2: people are sweeping water out of a house.
#  You answered: Cosine Similarity = 0.99023, Prediction = 1
#
# 15. Are the following sentences similar?
#     Sentence 1: a man plays a guitar.
#     Sentence 2: a man is playing a guitar.
#  You answered: Cosine Similarity = 0.97972, Prediction = 1
#
# 16. Are the following sentences similar?
#     Sentence 1: a man is playing a musical keyboard.
#     Sentence 2: a man is playing a keyboard piano.
#  You answered: Cosine Similarity = 0.99214, Prediction = 1
#
# 17. Are the following sentences similar?
#     Sentence 1: a man plays a trumpet.
#     Sentence 2: a man is playing the trumpet.
#  You answered: Cosine Similarity = 0.96605, Prediction = 1
#
# 18. Are the following sentences similar?
#     Sentence 1: the man is eating.
#     Sentence 2: a man is eating food.
#  You answered: Cosine Similarity = 0.98094, Prediction = 1
#
# 19. Are the following sentences similar?
#     Sentence 1: a person is slicing onions.
#     Sentence 2: someone is slicing an onion.
#  You answered: Cosine Similarity = 0.97537, Prediction = 1
#
# 20. Are the following sentences similar?
#     Sentence 1: two dogs and one cat sitting on couch.
#     Sentence 2: two dogs and a cat resting on a couch.
#  You answered: Cosine Similarity = 0.98111, Prediction = 1
#
# 21. Are the following sentences similar?
#     Sentence 1: two green and white trains sitting on the tracks.
#     Sentence 2: two green and white trains are sitting on the train track.
#  You answered: Cosine Similarity = 0.98960, Prediction = 1
#
# 22. Are the following sentences similar?
#     Sentence 1: a man in a top hat rides a white horse.
#     Sentence 2: a man with a top hat riding a white horse.
#  You answered: Cosine Similarity = 0.99210, Prediction = 1
#
# 23. Are the following sentences similar?
#     Sentence 1: blue and red plane in mid-air flight.
#     Sentence 2: a blue and red airplane while in flight.
#  You answered: Cosine Similarity = 0.96151, Prediction = 1
#
# 24. Are the following sentences similar?
#     Sentence 1: a group of horses grazing in a field.
#     Sentence 2: group of horses grazing in grassy field.
#  You answered: Cosine Similarity = 0.96566, Prediction = 1
#
# 25. Are the following sentences similar?
#     Sentence 1: three goats are being rounded up by a dog.
#     Sentence 2: three goats are chased by a dog.
#  You answered: Cosine Similarity = 0.98388, Prediction = 1
#
# 26. Are the following sentences similar?
#     Sentence 1: train in a station.
#     Sentence 2: a train in a station.
#  You answered: Cosine Similarity = 0.99132, Prediction = 1
#
# 27. Are the following sentences similar?
#     Sentence 1: a blue bird standing on a lawn.
#     Sentence 2: blue bird standing on green grass.
#  You answered: Cosine Similarity = 0.96458, Prediction = 1
#
# 28. Are the following sentences similar?
#     Sentence 1: a green car parked at a saloon.
#     Sentence 2: a green car parked outside the saloon.
#  You answered: Cosine Similarity = 0.98309, Prediction = 1
#
# 29. Are the following sentences similar?
#     Sentence 1: group of people sitting around a restaurant dining table.
#     Sentence 2: a group of people sitting at a restaurant table.
#  You answered: Cosine Similarity = 0.98184, Prediction = 1
#
# 30. Are the following sentences similar?
#     Sentence 1: a philips flat-screen tv is shown with its two remote controls.
#     Sentence 2: a phillips flat screen tv with two remote controls.
#  You answered: Cosine Similarity = 0.96769, Prediction = 1
#
# 31. Are the following sentences similar?
#     Sentence 1: the train sits at the train station.
#     Sentence 2: a train parked at a train station.
#  You answered: Cosine Similarity = 0.96782, Prediction = 1
#
# 32. Are the following sentences similar?
# ...
#
# 127. Are the following sentences similar?
#     Sentence 1: someone is drawing.
#     Sentence 2: someone is dancing.
#  You answered: Cosine Similarity = 0.91800, Prediction = 0
#
# 128. Are the following sentences similar?
#     Sentence 1: a person is playing a piano.
#     Sentence 2: a person is slicing a potato.
#  You answered: Cosine Similarity = 0.88269, Prediction = 0
#
# 129. Are the following sentences similar?
#     Sentence 1: a man is dancing.
#     Sentence 2: a woman is exercising.
#  You answered: Cosine Similarity = 0.91463, Prediction = 0
#
# 130. Are the following sentences similar?
#     Sentence 1: a woman is exercising.
#     Sentence 2: a man is dancing.
#  You answered: Cosine Similarity = 0.91463, Prediction = 0
#
# 131. Are the following sentences similar?
#     Sentence 1: a man is doing exercise.
#     Sentence 2: a man is firing a rifle.
#  You answered: Cosine Similarity = 0.90088, Prediction = 0
#
# 132. Are the following sentences similar?
#     Sentence 1: a man is playing a piano.
#     Sentence 2: a guy is peeling a potato.
#  You answered: Cosine Similarity = 0.86423, Prediction = 0
#
# 133. Are the following sentences similar?
#     Sentence 1: a man is bowling.
#     Sentence 2: a kitten is walking.
#  You answered: Cosine Similarity = 0.90558, Prediction = 0
#
# 134. Are the following sentences similar?
#     Sentence 1: a woman is dancing near a fire.
#     Sentence 2: a woman is cutting a tomatoe.
#  You answered: Cosine Similarity = 0.94377, Prediction = 0
#
# 135. Are the following sentences similar?
#     Sentence 1: a person is riding a motorcyle.
#     Sentence 2: a person is chopping an onion.
#  You answered: Cosine Similarity = 0.83578, Prediction = 0
#
# 136. Are the following sentences similar?
#     Sentence 1: a man is talking on the phone.
#     Sentence 2: a man is moon-walking across a store.
#  You answered: Cosine Similarity = 0.96557, Prediction = 1
#
# 137. Are the following sentences similar?
#     Sentence 1: a woman is braiding her hair.
#     Sentence 2: a man is riding a motorcycle.
#  You answered: Cosine Similarity = 0.84749, Prediction = 0
#
# 138. Are the following sentences similar?
#     Sentence 1: the woman is slicing tofu.
#     Sentence 2: the woman is putting on lipstick.
#  You answered: Cosine Similarity = 0.90419, Prediction = 0
#
# 139. Are the following sentences similar?
#     Sentence 1: a woman is folding paper.
#     Sentence 2: a woman is applying eye shadow.
#  You answered: Cosine Similarity = 0.93288, Prediction = 0
#
# 140. Are the following sentences similar?
#     Sentence 1: someone is folding a piece of paper.
#     Sentence 2: a person is slicing a small pieces of ginger.
#  You answered: Cosine Similarity = 0.94615, Prediction = 0
#
# 141. Are the following sentences similar?
#     Sentence 1: a man is lifting weights.
#     Sentence 2: a man is chopping egg plant.
#  You answered: Cosine Similarity = 0.85623, Prediction = 0
#
# 142. Are the following sentences similar?
#     Sentence 1: a man is playing a cello.
#     Sentence 2: a man is rapidly lifting small weights.
#  You answered: Cosine Similarity = 0.84074, Prediction = 0
#
# 143. Are the following sentences similar?
#     Sentence 1: the man is talking.
#     Sentence 2: a man is walking down stairs.
#  You answered: Cosine Similarity = 0.90752, Prediction = 0
#
# 144. Are the following sentences similar?
#     Sentence 1: a man is playing the drums.
#     Sentence 2: a woman is slicing some leaves.
#  You answered: Cosine Similarity = 0.86408, Prediction = 0
#
# 145. Are the following sentences similar?
#     Sentence 1: a man is hitting a boy with flower vase.
#     Sentence 2: a man is cutting a mat.
#  You answered: Cosine Similarity = 0.93876, Prediction = 0
#
# 146. Are the following sentences similar?
#     Sentence 1: the man is mixing whipping cream.
#     Sentence 2: the man is holding a skunk.
#  You answered: Cosine Similarity = 0.86777, Prediction = 0
#
# 147. Are the following sentences similar?
#     Sentence 1: a man is singing while playing the guitar.
#     Sentence 2: a man is stuffing himself full with food.
#  You answered: Cosine Similarity = 0.86546, Prediction = 0
#
# 148. Are the following sentences similar?
#     Sentence 1: a boat sails along the water.
#     Sentence 2: the man is playing the guitar.
#  You answered: Cosine Similarity = 0.75198, Prediction = 0
#
# 149. Are the following sentences similar?
#     Sentence 1: an okapi is eating from a tree.
#     Sentence 2: a moose drinks from a sprinkler.
#  You answered: Cosine Similarity = 0.89702, Prediction = 0
#
# 150. Are the following sentences similar?
#     Sentence 1: a woman is pouring egg into a frying pan.
#     Sentence 2: a man is petting two dogs.
#  You answered: Cosine Similarity = 0.84205, Prediction = 0
#
# 151. Are the following sentences similar?
#     Sentence 1: a woman is frying ground meat.
#     Sentence 2: a man is cutting a trunk with an axe.
#  You answered: Cosine Similarity = 0.88743, Prediction = 0
#
# 152. Are the following sentences similar?
#     Sentence 1: a person is boiling noodles.
#     Sentence 2: a cat is licking a bottle.
#  You answered: Cosine Similarity = 0.84776, Prediction = 0
#
# 153. Are the following sentences similar?
#     Sentence 1: a man reels in a fish.
#     Sentence 2: a woman is pouring oil in a bowl.
#  You answered: Cosine Similarity = 0.92006, Prediction = 0
#
# 154. Are the following sentences similar?
#     Sentence 1: a woman is cutting an onion.
#     Sentence 2: a horse is standing.
#  You answered: Cosine Similarity = 0.91819, Prediction = 0
#
# 155. Are the following sentences similar?
#     Sentence 1: a person is adding food in a pan.
#     Sentence 2: a man is dancing in the street.
#  You answered: Cosine Similarity = 0.91161, Prediction = 0
#
# 156. Are the following sentences similar?
#     Sentence 1: a man is smoking.
#     Sentence 2: a baby is sucking on a pacifier.
#  You answered: Cosine Similarity = 0.90412, Prediction = 0
#
# 157. Are the following sentences similar?
#     Sentence 1: a person is putting shredded cheese in a pot.
#     Sentence 2: a hamster is eating some seeds.
#  You answered: Cosine Similarity = 0.89489, Prediction = 0
#
# 158. Are the following sentences similar?
#     Sentence 1: a man is erasing a chalk board.
#     Sentence 2: a woman is dancing, and singing.
#  You answered: Cosine Similarity = 0.84711, Prediction = 0
#
# 159. Are the following sentences similar?
#     Sentence 1: a chimp is kicking a target.
#     Sentence 2: a woman is putting oil into a skillet.
#  You answered: Cosine Similarity = 0.89497, Prediction = 0
#
# 160. Are the following sentences similar?
#     Sentence 1: a man is doing exercise.
#     Sentence 2: a baby is laughing.
#  You answered: Cosine Similarity = 0.91470, Prediction = 0
#
# 161. Are the following sentences similar?
#     Sentence 1: the girl is carrying a baby.
#     Sentence 2: a man is eating a food.
#  You answered: Cosine Similarity = 0.92777, Prediction = 0
#
# 162. Are the following sentences similar?
#     Sentence 1: a man spins on a surf board.
#     Sentence 2: a man is putting barbecue sauce on chicken.
#  You answered: Cosine Similarity = 0.85922, Prediction = 0
#
# 163. Are the following sentences similar?
#     Sentence 1: two men are dancing together.
#     Sentence 2: a woman opens a closet.
#  You answered: Cosine Similarity = 0.67956, Prediction = 0
#
# 164. Are the following sentences similar?
#     Sentence 1: a man is reading an email.
#     Sentence 2: a person opening a banana.
#  You answered: Cosine Similarity = 0.87865, Prediction = 0
#
# 165. Are the following sentences similar?
#     Sentence 1: the flock of sheep are spread out in the field.
#     Sentence 2: a white cat stands on the floor.
#  You answered: Cosine Similarity = 0.87089, Prediction = 0
#
# 166. Are the following sentences similar?
#     Sentence 1: a man sitting in a back yard playing the guitar.
#     Sentence 2: a man riding on the back of an orange suv.
#  You answered: Cosine Similarity = 0.93088, Prediction = 0
#
# 167. Are the following sentences similar?
#     Sentence 1: a woman riding a brown horse.
#     Sentence 2: a woman taking her own photo from above.
#  You answered: Cosine Similarity = 0.87772, Prediction = 0
#
# 168. Are the following sentences similar?
#     Sentence 1: two men standing in grass staring at a car.
#     Sentence 2: a woman in a pink top posing with beer.
#  You answered: Cosine Similarity = 0.90079, Prediction = 0
#
# 169. Are the following sentences similar?
#     Sentence 1: the train heads down the tracks and along the hedge.
#     Sentence 2: a dog on the floor of a patio looks at a cat on the fence.
#  You answered: Cosine Similarity = 0.90412, Prediction = 0
#
# 170. Are the following sentences similar?
#     Sentence 1: a little girl is laughing at the camera.
#     Sentence 2: a white cow with big ears looking into the camera.
#  You answered: Cosine Similarity = 0.93659, Prediction = 0
#
# 171. Are the following sentences similar?
#     Sentence 1: a man dressed in a pale scarf with a stick.
#     Sentence 2: a runner is resting in the shade with a bottle of soda.
#  You answered: Cosine Similarity = 0.91724, Prediction = 0
#
# 172. Are the following sentences similar?
#     Sentence 1: a very retro living room with a television in it.
#     Sentence 2: a grey cat lying on a wooden table.
#  You answered: Cosine Similarity = 0.86874, Prediction = 0
#
# 173. Are the following sentences similar?
#     Sentence 1: a man sitting cross legged on the grass, with a tree in the background.
#     Sentence 2: ocean liner close to coast with houses in the background.
#  You answered: Cosine Similarity = 0.90083, Prediction = 0
#
# 174. Are the following sentences similar?
#     Sentence 1: two men standing in grass staring at a car.
#     Sentence 2: two women sitting in chairs in a shop.
#  You answered: Cosine Similarity = 0.94868, Prediction = 0
#
# 175. Are the following sentences similar?
#     Sentence 1: a woman stands in front of a building in the snow.
#     Sentence 2: two women and a baby pose in front of a dining room.
#  You answered: Cosine Similarity = 0.95404, Prediction = 1
#
# 176. Are the following sentences similar?
#     Sentence 1: a yellow school bus parked in a field.
#     Sentence 2: a brown horse in a green field.
#  You answered: Cosine Similarity = 0.91766, Prediction = 0
#
# 177. Are the following sentences similar?
#     Sentence 1: the cat is sitting on a bag of cat food.
#     Sentence 2: two eagles sitting on a long branch.
#  You answered: Cosine Similarity = 0.88191, Prediction = 0
#
# 178. Are the following sentences similar?
#     Sentence 1: a women painting a chair with a dining room in the background.
#     Sentence 2: a man and boy walking along a beach with the sea in the background.
#  You answered: Cosine Similarity = 0.93913, Prediction = 0
#
# 179. Are the following sentences similar?
#     Sentence 1: a cruise ship is in front of a docking area.
#     Sentence 2: calico cat sitting on step in front of a door.
#  You answered: Cosine Similarity = 0.91744, Prediction = 0
#
# 180. Are the following sentences similar?
#     Sentence 1: a black and white cow standing in hay looks back at the camera.
#     Sentence 2: there is a black and white sheep standing on the grass.
#  You answered: Cosine Similarity = 0.96517, Prediction = 1
#
# 181. Are the following sentences similar?
#     Sentence 1: two animals sitting on a rock.
#     Sentence 2: the brown train is sitting on the railroad tracks.
#  You answered: Cosine Similarity = 0.91463, Prediction = 0
#
# 182. Are the following sentences similar?
#     Sentence 1: a small camouflaged airplane parked in the grass.
#     Sentence 2: a small dog wearing a pink shirt tied to a railing.
#  You answered: Cosine Similarity = 0.88214, Prediction = 0
#
# 183. Are the following sentences similar?
#     Sentence 1: a man and a woman watch two dogs.
#     Sentence 2: a man in a maroon bathing suit swings on a rope on a lake.
#  You answered: Cosine Similarity = 0.91789, Prediction = 0
#
# 184. Are the following sentences similar?
#     Sentence 1: a man and a woman are standing in front of a building
#     Sentence 2: two girls are sitting on an atv on the sand in front of a bridge.
#  You answered: Cosine Similarity = 0.96758, Prediction = 1
#
# 185. Are the following sentences similar?
#     Sentence 1: a woman in a black and orange jacket throws a stick for a brown and black dog to fetch.
#     Sentence 2: the man in a blue jacket is standing in a crowd.
#  You answered: Cosine Similarity = 0.95327, Prediction = 1
#
# 186. Are the following sentences similar?
#     Sentence 1: two racing dogs run in the mud.
#     Sentence 2: the man is going into the water.
#  You answered: Cosine Similarity = 0.89808, Prediction = 0
#
# 187. Are the following sentences similar?
#     Sentence 1: a man in a suit dances with a young girl in front of an audience.
#     Sentence 2: a women dangles from a blue fabric connected to a tree.
#  You answered: Cosine Similarity = 0.93730, Prediction = 0
#
# 188. Are the following sentences similar?
#     Sentence 1: a man and woman walking past a record shop
#     Sentence 2: a man and woman kissing in front of a crowd of people.
#  You answered: Cosine Similarity = 0.95359, Prediction = 1
#
# 189. Are the following sentences similar?
#     Sentence 1: a boy in red jumping into a sandbox.
#     Sentence 2: a dog swimming in a pond
#  You answered: Cosine Similarity = 0.92932, Prediction = 0
#
# 190. Are the following sentences similar?
#     Sentence 1: two people are in bed.
#     Sentence 2: two boxers are in the ring.
#  You answered: Cosine Similarity = 0.92851, Prediction = 0
#
# 191. Are the following sentences similar?
#     Sentence 1: a red haired women in black is posing for a man while resting on a tree.
#     Sentence 2: a man in a black shirt is holding a child wearing sunglasses.
#  You answered: Cosine Similarity = 0.96139, Prediction = 1
#
# 192. Are the following sentences similar?
#     Sentence 1: a dog standing in the water.
#     Sentence 2: a girl playing on a parachute.
#  You answered: Cosine Similarity = 0.89931, Prediction = 0
#
# 193. Are the following sentences similar?
#     Sentence 1: a brown and white dog is running across a brown field.
#     Sentence 2: a person hanging from a rocky cliff.
#  You answered: Cosine Similarity = 0.92439, Prediction = 0
#
# 194. Are the following sentences similar?
#     Sentence 1: a man in a wet suit is throwing a baby wearing a wet suit up into the air.
#     Sentence 2: a man in a white print shirt and a woman in a black dress dancing.
#  You answered: Cosine Similarity = 0.96227, Prediction = 1
#
# 195. Are the following sentences similar?
#     Sentence 1: many football players sitting on the ground.
#     Sentence 2: a dog rolls on the ground.
#  You answered: Cosine Similarity = 0.86310, Prediction = 0
#
# 196. Are the following sentences similar?
#     Sentence 1: a little boy and a little girl playing together outside.
#     Sentence 2: a woman wearing a white shirt stands on the street.
#  You answered: Cosine Similarity = 0.89065, Prediction = 0
#
# 197. Are the following sentences similar?
#     Sentence 1: the woman is holding the harness that the brown and white dog is wearing.
#     Sentence 2: a man and woman are looking at artwork that is on easels and clipped to a fencing wall.
#  You answered: Cosine Similarity = 0.95185, Prediction = 1
#
# 198. Are the following sentences similar?
#     Sentence 1: a young pitcher is throwing the baseball.
#     Sentence 2: a brown dog is walking on the grass beside a fence.
#  You answered: Cosine Similarity = 0.88380, Prediction = 0
#
# 199. Are the following sentences similar?
#     Sentence 1: a woman in a blue bathing suit is jumping off a dock into a lake.
#     Sentence 2: a boy in a blue shirt and blue jeans runs across a playground
#  You answered: Cosine Similarity = 0.93599, Prediction = 0
#
# 200. Are the following sentences similar?
#     Sentence 1: a little girl in an orange striped outfit is airborne whilst bouncing on a bed.
#     Sentence 2: a dog in a red shirt is chasing a squirrel through the glass.
#  You answered: Cosine Similarity = 0.97864, Prediction = 1
#
# accuracy using sum of word vectors : 0.92000
# accuracy using sum of word vectors with POS weights : 0.92500

# %% [markdown]
# Note that our tester is using a threshold of 0.95 for the similarity score, i.e. we consider the prediction as 1 if cosine similarity return by your function is greater than 0.95, else consider it as 0. You should expect the following accuracies:
#
# accuracy using sum of word vectors : 0.85
#
# accuracy using sum of word vectors with POS weights : 0.925

# %% [markdown]
# ### Exercise 5. K-Nearest Neighbors Classifier using Glove-Based Sentence Embeddings (4 pts)
#
# We will now utilize the sentence representations to build a K-Nearest Neighbors (KNN) classifier. A KNN classifier classifies a sentence by finding its nearest neighbors (in the embedding space) in the training data and taking a majority vote of the labels of neighbors.
#
#
#  We will be working with the STS dataset from HW1, i.e. classifying the sentiment of movie reviews (we will consider both binary and 5-class classification case). You will implement the following class:
#
# `GloveKNNClassifier` with methods:
# - `__init__`: Initialize the classifier with the value of k and the choice of sentence embedding method (simple sum or sum with POS weights)
# - `fit`: Calculates the sentence embeddings for all sentences in the training data and stores them. Also stores the corresponding labels.
# - `predict`: Predicts the label(s) for the given sentence(s) using the K-Nearest Neighbors algorithm. The distance metric to use is cosine similarity.
#
# Helpful Tips:
#
# - Lower case the training as well as test sentences before computing their embeddings (if your `get_sentence_embedding` already handles that for you, you don't need to do it again here)
#
# - To avoid division by zero when calculating cosine similarity, you can add a small epsilon value i.e. 1e-8 to the denominator.
#
# - We strongly recommend implementing a vectorized version of `cosine_similarity` here, i.e. instead of one by one computing similarity between a test sentence and a training sentence, implement a function which takes n test sentences and m train sentences and uses matrix multiplication operations to get a similarity matrix of shape [n, m]

# %%
class GloveKNNClassifier:

    def __init__(self, word_embeddings: GloveEmbeddings, k: int = 5, use_POS: bool = False, pos_weights: Dict[str, float] = None):
        """
        Initialize the KNN Classifier.
        Inputs:
        - word_embeddings: GloveEmbeddings object
        - k: Number of nearest neighbors to consider
        - use_POS: Whether to use POS tag based weights for the embeddings
        - pos_weights: Dictionary containing POS weights

        """

        # YOUR CODE HERE
        self.word_embeddings = word_embeddings
        self.k = k
        self.use_POS = use_POS
        self.pos_weights = pos_weights
        self.X = torch.Tensor
        self.y = torch.Tensor

    def fit(self, X_train: List[str], y_train: List[int]):
        """
        Fit the KNN Classifier by calculating the sentence embeddings for the training sentences and storing them. Also store the corresponding labels.
        Inputs:
        - X_train: List of training sentences (documents)
        - y_train: List of corresponding labels
        """

        # YOUR CODE HERE
        self.X = torch.stack([get_sentence_embedding(sentence, self.word_embeddings, self.use_POS, self.pos_weights) for sentence in X_train])
        self.y = torch.tensor(y_train)

    def predict(self, X_test: List[str]) -> List[int]:
        """
        Predicts the labels for the test sentences using the training data embeddings.

        Inputs:
        - X_test: List of test sentences

        Returns:
        - List of predicted labels

        Hint: `torch.topk` might be useful here.
        """

        closest_k = torch.topk(
            self.cosine_similarity_vectorized(
                torch.stack(
                    [get_sentence_embedding(sentence, self.word_embeddings, self.use_POS, self.pos_weights) for sentence in X_test]
                ), self.X), 
            self.k, dim=1)
        labels = self.y[closest_k.indices]
        
        # YOUR CODE HERE
        return labels.mode().values.tolist()

    # Any extra functions you need can be added here
    # YOUR CODE HERE
    def cosine_similarity_vectorized(self, v1: torch.Tensor, v2: torch.Tensor) -> torch.Tensor:
        """
        Compute the cosine similarity between two vectors.

        Inputs:
        v1: torch.Tensor of shape (n,k)
        v2: torch.Tensor of shape (m,k)

        Returns:
        torch.Tensor: cosine similarity between v1 and v2
        """

        # YOUR CODE HERE
        return (v1 @ v2.T 
                / 
                (torch.norm(v1, dim=1).unsqueeze(1) * torch.norm(v2, dim=1).unsqueeze(0) + 1e-8))

# %%
######################################################
#  The following code is given to you. DO NOT MODIFY.
######################################################

exercise5 = Exercise5Runner(GloveKNNClassifier)
exercise5.evaluate(k=5)
# Out:
# Excercise 5: KNN Classifier
# -----------------
# Binary Classification using k = 5 using sum of word vectors
# Accuracy on train set: 0.77645
# Accuracy on dev set: 0.66848
#
# Multiclass Classification using k = 5 using sum of word vectors
# Accuracy on train set: 0.52727
# Accuracy on dev set: 0.30336
#
# Binary Classification using k = 5 using sum of word vectors with POS weights
# Accuracy on train set: 0.77259
# Accuracy on dev set: 0.63306
#
# Multiclass Classification using k = 5 using sum of word vectors with POS weights
# Accuracy on train set: 0.52224
# Accuracy on dev set: 0.27702

# %% [markdown]
# You should see the following accuracies:
#
# Binary Classification:
# - Train accuracy using sum of word vectors : 0.76884
# - Dev accuracy using sum of word vectors with POS weights : 0.65849
#
# - Train accuracy using sum of word vectors with POS weights : 0.77142
# - Dev accuracy using sum of word vectors with POS weights : 0.63397
#
# Multi-class Classification:
# - Train accuracy using sum of word vectors : 0.52037
# - Dev accuracy using sum of word vectors with POS weights : 0.30609
#
# - Train accuracy using sum of word vectors with POS weights : 0.52095
# - Dev accuracy using sum of word vectors with POS weights : 0.27611
#
# A good way to debug your code can be to check if you get 100% train accuracies for all the cases when you use `k = 1`, since the closest point to a point is the point itself. You can check that by running:
#
# ```
# exercise5.evaluate(k=1)
# ```

# %%
# effect of k on KNN Classifier Performance
def get_effect_of_k_on_knn_performance():
    ks = [1, 3, 5, 7, 9, 19, 29, 39, 49]
    
    binary_train_accs = []
    binary_dev_accs = []
    multi_train_accs = []
    multi_dev_accs = []
    for k in ks:
        accs = exercise5.evaluate(k=k, return_vals=True)
        binary_train_accs.append(accs['binary']['sum']['train'])
        binary_dev_accs.append(accs['binary']['sum']['dev'])
        multi_train_accs.append(accs['multiclass']['sum']['train'])
        multi_dev_accs.append(accs['multiclass']['sum']['dev'])

    # plot the accuracies
    plt.figure()
    plt.plot(ks, binary_train_accs, label="Binary Train")
    plt.plot(ks, binary_dev_accs, label="Binary Dev")
    plt.plot(ks, multi_train_accs, label="Multi Train")
    plt.plot(ks, multi_dev_accs, label="Multi Dev")
    plt.xlabel("k")
    plt.ylabel("Accuracy")
    plt.legend()
    plt.show()

get_effect_of_k_on_knn_performance()
# Out:
# Excercise 5: KNN Classifier
# -----------------
# Binary Classification using k = 1 using sum of word vectors
# Accuracy on train set: 0.99941
# Accuracy on dev set: 0.61580
#
# Multiclass Classification using k = 1 using sum of word vectors
# Accuracy on train set: 0.99941
# Accuracy on dev set: 0.29519
#
# Binary Classification using k = 1 using sum of word vectors with POS weights
# Accuracy on train set: 0.99941
# Accuracy on dev set: 0.62489
#
# Multiclass Classification using k = 1 using sum of word vectors with POS weights
# Accuracy on train set: 0.99941
# Accuracy on dev set: 0.29700
# Excercise 5: KNN Classifier
# -----------------
# Binary Classification using k = 3 using sum of word vectors
# Accuracy on train set: 0.81437
# Accuracy on dev set: 0.64941
#
# Multiclass Classification using k = 3 using sum of word vectors
# Accuracy on train set: 0.57877
# Accuracy on dev set: 0.27793
#
# Binary Classification using k = 3 using sum of word vectors with POS weights
# Accuracy on train set: 0.81156
# Accuracy on dev set: 0.61944
#
# Multiclass Classification using k = 3 using sum of word vectors with POS weights
# Accuracy on train set: 0.57959
# Accuracy on dev set: 0.26249
# Excercise 5: KNN Classifier
# -----------------
# Binary Classification using k = 5 using sum of word vectors
# Accuracy on train set: 0.77645
# Accuracy on dev set: 0.66848
#
# Multiclass Classification using k = 5 using sum of word vectors
# Accuracy on train set: 0.52727
# Accuracy on dev set: 0.30336
#
# Binary Classification using k = 5 using sum of word vectors with POS weights
# Accuracy on train set: 0.77259
# Accuracy on dev set: 0.63306
#
# Multiclass Classification using k = 5 using sum of word vectors with POS weights
# Accuracy on train set: 0.52224
# Accuracy on dev set: 0.27702
# Excercise 5: KNN Classifier
# -----------------
# Binary Classification using k = 7 using sum of word vectors
# Accuracy on train set: 0.75574
# Accuracy on dev set: 0.68120
#
# Multiclass Classification using k = 7 using sum of word vectors
# Accuracy on train set: 0.49239
# Accuracy on dev set: 0.30518
#
# Binary Classification using k = 7 using sum of word vectors with POS weights
# Accuracy on train set: 0.75550
# Accuracy on dev set: 0.65395
#
# Multiclass Classification using k = 7 using sum of word vectors with POS weights
# Accuracy on train set: 0.48923
# Accuracy on dev set: 0.29700
# Excercise 5: KNN Classifier
# -----------------
# Binary Classification using k = 9 using sum of word vectors
# Accuracy on train set: 0.74590
# Accuracy on dev set: 0.69119
#
# Multiclass Classification using k = 9 using sum of word vectors
# Accuracy on train set: 0.47097
# Accuracy on dev set: 0.32062
#
# Binary Classification using k = 9 using sum of word vectors with POS weights
# Accuracy on train set: 0.74356
# Accuracy on dev set: 0.66031
#
# Multiclass Classification using k = 9 using sum of word vectors with POS weights
# Accuracy on train set: 0.47554
# Accuracy on dev set: 0.31789
# Excercise 5: KNN Classifier
# -----------------
# Binary Classification using k = 19 using sum of word vectors
# Accuracy on train set: 0.72308
# Accuracy on dev set: 0.71571
#
# Multiclass Classification using k = 19 using sum of word vectors
# Accuracy on train set: 0.42767
# Accuracy on dev set: 0.33333
#
# Binary Classification using k = 19 using sum of word vectors with POS weights
# Accuracy on train set: 0.71664
# Accuracy on dev set: 0.69573
#
# Multiclass Classification using k = 19 using sum of word vectors with POS weights
# Accuracy on train set: 0.42966
# Accuracy on dev set: 0.33424
# Excercise 5: KNN Classifier
# -----------------
# Binary Classification using k = 29 using sum of word vectors
# Accuracy on train set: 0.71091
# Accuracy on dev set: 0.72116
#
# Multiclass Classification using k = 29 using sum of word vectors
# Accuracy on train set: 0.40906
# Accuracy on dev set: 0.34696
#
# Binary Classification using k = 29 using sum of word vectors with POS weights
# Accuracy on train set: 0.71606
# Accuracy on dev set: 0.69210
#
# Multiclass Classification using k = 29 using sum of word vectors with POS weights
# Accuracy on train set: 0.41409
# Accuracy on dev set: 0.33697
# Excercise 5: KNN Classifier
# -----------------
# Binary Classification using k = 39 using sum of word vectors
# Accuracy on train set: 0.71103
# Accuracy on dev set: 0.71026
#
# Multiclass Classification using k = 39 using sum of word vectors
# Accuracy on train set: 0.40063
# Accuracy on dev set: 0.34423
#
# Binary Classification using k = 39 using sum of word vectors with POS weights
# Accuracy on train set: 0.71009
# Accuracy on dev set: 0.70572
#
# Multiclass Classification using k = 39 using sum of word vectors with POS weights
# Accuracy on train set: 0.39958
# Accuracy on dev set: 0.33333
# Excercise 5: KNN Classifier
# -----------------
# Binary Classification using k = 49 using sum of word vectors
# Accuracy on train set: 0.70588
# Accuracy on dev set: 0.69846
#
# Multiclass Classification using k = 49 using sum of word vectors
# Accuracy on train set: 0.39139
# Accuracy on dev set: 0.34696
#
# Binary Classification using k = 49 using sum of word vectors with POS weights
# Accuracy on train set: 0.70236
# Accuracy on dev set: 0.69755
#
# Multiclass Classification using k = 49 using sum of word vectors with POS weights
# Accuracy on train set: 0.39349
# Accuracy on dev set: 0.34968

# %% [markdown]
# You must have noticed that the nearest neighbor classifier with glove embeddings doesn't perform very good, in fact it performs worse than the the linear classifiers we trained in HW1. One of the reasons why this happens is because the way we construct the sentence embeddings by summing the word embeddings? Can you think of the issues with such approach?

# %% [markdown]
# ### Exercise 6:  K-Nearest Neighbors Classifier using Transformer Based Sentence Embeddings (3 pts)
#
# We will now utilize pre-trained transformers based sentence embeddings to build our KNN classifier. These embeddings are trained a large text corpora and learn sentence level representations which are much more powerful than the simple sum of word embeddings.
# While we haven't covered transformers based sentence embeddings in the class yet, we would like to give you a flavour of how the directly trained sentence level representations can be more powerful. We will be using the `sentence-transformers` library to get the sentence embeddings. Below we provide you with a helper function `get_st_embeddings` which takes in a list of sentences, and a sentence transformers model, and returns the sentence embeddings using the `sentence-transformers` library.

# %%
######################################################
#  The following code is given to you. DO NOT MODIFY.
######################################################
from sentence_transformers import SentenceTransformer

def get_st_embeddings(
    sentences: List[str],
    st_model: SentenceTransformer,
    batch_size: int = 32,
    device: str = "cpu",
):
    """
    Compute the sentence embedding using the Sentence Transformer model.

    Inputs:
    - sentence: The input sentence
    - st_model: SentenceTransformer model
    - batch_size: Encode in batches to avoid memory issues in case multiple sentences are passed

    Returns:
    torch.Tensor: The sentence embedding of shape [d,] (when only 1 sentence) or [n, d] where n is the number of sentences and d is the embedding dimension
    """

    st_model.to(device)
    sentence_embeddings = None

    for i in range(0, len(sentences), batch_size):
        batch_sentences = sentences[i : i + batch_size]
        batch_embeddings = st_model.encode(batch_sentences, convert_to_tensor=True)
        if sentence_embeddings is None:
            sentence_embeddings = batch_embeddings
        else:
            sentence_embeddings = torch.cat(
                [sentence_embeddings, batch_embeddings], dim=0
            )

    return sentence_embeddings.to("cpu")

# %%
# Example usage

# Load model
st_model = SentenceTransformer(
    "all-mpnet-base-v2"
)  # You can use any model from the Sentence Transformers library. See the list here: https://sbert.net/docs/sentence_transformer/pretrained_models.html

# Get embeddings
sent_embeddings = get_st_embeddings(
    ["This is a test sentence", "This is another test sentence"], st_model
)
print(sent_embeddings.shape)
# Out:
# torch.Size([2, 768])

# %%
class SentenceTransformerKNNClassifier(GloveKNNClassifier):

    def __init__(
        self, st_model: str = "all-mpnet-base-v2", k: int = 5, batch_size: int = 128
    ):

        super().__init__(None, k)

        self.st_model = SentenceTransformer(st_model)
        self.k = k
        self.batch_size = batch_size

    def fit(self, X_train: List[str], y_train: List[int]):

        # YOUR CODE HERE
        self.X = get_st_embeddings(X_train, self.st_model, self.batch_size)
        self.y = torch.tensor(y_train)

    def predict(self, X_test: List[str]) -> List[int]:

        # YOUR CODE HERE
        closest_k = torch.topk(
            self.cosine_similarity_vectorized(
                get_st_embeddings(X_test, self.st_model, self.batch_size), self.X), 
            self.k, dim=1)
        labels = self.y[closest_k.indices]
        
        # YOUR CODE HERE
        return labels.mode().values.tolist()

    # Any extra functions you need can be added here
    # YOUR CODE HERE
    def cosine_similarity_vectorized(self, v1: torch.Tensor, v2: torch.Tensor) -> torch.Tensor:
        """
        Compute the cosine similarity between two vectors.

        Inputs:
        v1: torch.Tensor of shape (n,k)
        v2: torch.Tensor of shape (m,k)

        Returns:
        torch.Tensor: cosine similarity between v1 and v2
        """

        # YOUR CODE HERE
        return (v1 @ v2.T 
                / 
                (torch.norm(v1, dim=1).unsqueeze(1) * torch.norm(v2, dim=1).unsqueeze(0) + 1e-8))

# %%
######################################################
#  The following code is given to you. DO NOT MODIFY.
######################################################
# You can first evaluate your implementation on debug mode that only uses a fraction of train and dev sets
exercise6 = Exercise6Runner(SentenceTransformerKNNClassifier)
exercise6.evaluate(k=10, debug=True)
# Out:
# Excercise 6: Sentence Transformer KNN Classifier
# -----------------
# Running on Debug Model. Will only use 100 examples in training and 10 examples for dev set
#
# Binary Classification using k = 10 using Sentence Transformer
# Accuracy on dev set: 0.90000
#
# Multiclass Classification using k = 10 using Sentence Transformer
# Accuracy on dev set: 0.30000

# %% [markdown]
# In the debug model you should see a dev accuracy of 0.9 for binary case and 0.3 for multi-class case. Note that these are not the actual accuracy values, but a way to check if your code is running without any errors. Once you are satisfied with the debug accuracies, you can run the code below to get the actual accuracies.

# %%
######################################################
#  The following code is given to you. DO NOT MODIFY.
######################################################
# This will take a while to run (can take upto 40 minutes).
# You can reduce the runtime by using a GPU runtime and using device="cuda" while calling `get_st_embeddings` function.

exercise6 = Exercise6Runner(SentenceTransformerKNNClassifier)
exercise6.evaluate(k=10, debug=False)
# Out:
# Excercise 6: Sentence Transformer KNN Classifier
# -----------------
# Binary Classification using k = 10 using Sentence Transformer
# Accuracy on dev set: 0.81471
#
# Multiclass Classification using k = 10 using Sentence Transformer
# Accuracy on dev set: 0.42507

# %% [markdown]
# You should see the following accuracies:
#
# Binary Classification:
# - Dev accuracy: 0.81471
#
# Multi-class Classification:
# - Dev accuracy: 0.42507

# %% [markdown]
# As you can see we get much better numbers than the glove embeddings (a 10% improvement). We can further improve these numbers by fine-tuning the transformer model on our specific task, but that is out of the scope of this assignment.
